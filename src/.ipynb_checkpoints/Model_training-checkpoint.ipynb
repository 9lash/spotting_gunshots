# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = (12,8)
import numpy as np
import tensorflow as tf
import keras
import pandas as pd
from keras_tqdm import TQDMNotebookCallback

# %%
from keras.preprocessing.sequence import pad_sequences

def data_generator(batch_size, tfrecord, start_frac=0, end_frac=1):
    '''
    Shuffles the Audioset training data and returns a generator of training data and boolean laughter labels
    batch_size: batch size for each set of training data and labels
    tfrecord: filestring of the tfrecord file to train on
    start_frac: the starting point of the data set to use, as a fraction of total record length (used for CV)
    end_frac: the ending point of the data set to use, as a fraction of total record length (used for CV)
    '''
    max_len=10
    #tfrecord holds data in binary sequence string. 
    records = list(tf.python_io.tf_record_iterator(tfrecord))  #records holds the array of the tfrecord file
    if(tfrecord == '../data/preprocessed/unbaltrain_spotting_gunshots_subset.tfrecord'):
        print("Total audioframes in training dataset:", len(records))
    elif(tfrecord == '../data/preprocessed/eval_spotting_gunshots_subset.tfrecord'):
        print("Total audioframes in eval dataset:", len(records))
        
    records = records[int(start_frac*len(records)):int(end_frac*len(records))]  # Make train_set & CV_set 
    print("After fractioning:")
    if(tfrecord == '../data/preprocessed/unbaltrain_spotting_gunshots_subset.tfrecord'):
        print("Total audioframes in training dataset:", len(records))
    elif(tfrecord == '../data/preprocessed/eval_spotting_gunshots_subset.tfrecord'):
        print("Total audioframes in eval dataset:", len(records))
    
    rec_len = len(records)  # this is your train set, rest is CV_set
    shuffle = np.random.permutation(range(rec_len))
    num_batches = rec_len//batch_size - 1                      
    j = 0
    
    gun_labels = [426,427,428,429,430,431]
#     fireworks_labels = [432,433,434]
#     background_labels= [506,507,508,509,510,511,512,513,514,515,516,517,518,519,520,521,522,523,524,525,526]
#     other_labels =[]
    
    while True:
        X = []
        y = []  #add g=[],f=[],b=[],other=[]
        for idx in shuffle[j*batch_size:(j+1)*batch_size]:
            example = records[idx]
            tf_seq_example = tf.train.SequenceExample.FromString(example)
            example_label = list(np.asarray(tf_seq_example.context.feature['labels'].int64_list.value))
            value_x = any((True for x in example_label if x in gun_labels)) #add f_bin, b_bin, other_bin
            if(value_x==True):
                y.append(1)      #[1,1,0,1,0...] 
            else:
                y.append(0)
                
            n_frames = len(tf_seq_example.feature_lists.feature_list['audio_embedding'].feature)
            audio_frame = []
            for i in range(n_frames):
                audio_frame.append(np.frombuffer(tf_seq_example.feature_lists.feature_list['audio_embedding'].
                                                         feature[i].bytes_list.value[0],np.uint8).astype(np.float32)) # audio_frame gets 128 8 bit numbers on each for loop iteration
            pad = [np.zeros([128], np.float32) for i in range(max_len-n_frames)] 
            # if clip is less than 10 sec, audio_frame is padded with zeros for 
            #rest of the secs to make it to 10 sec.
            
            audio_frame += pad
            X.append(audio_frame) #eg: X[5] will output 5th audioframe 

        j += 1
        if j >= num_batches:
            shuffle = np.random.permutation(range(rec_len))
            j = 0

        X = np.array(X)
        yield X, np.array(y)

# %%
#Logistic Regression

# %%
from keras.models import Sequential
from keras.layers import Dense, BatchNormalization, Flatten

lr_model = Sequential()
# lr_model.add(Flatten(input_shape = (10,128)))
lr_model.add(BatchNormalization(input_shape=(10, 128)))
lr_model.add(Flatten())
lr_model.add(Dense(1, activation='sigmoid'))                
lr_model.compile(loss = 'binary_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])
# Out:
# WARNING:tensorflow:From /Users/abhilash/anaconda3/envs/avacado/lib/python3.7/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %%
batch_size=  40 
CV_frac = 0.1
train_gen = data_generator(batch_size,'../data/preprocessed/unbaltrain_spotting_gunshots_subset.tfrecord') #, 0, 1-CV_frac)
val_gen = data_generator(20,'../data/preprocessed/eval_spotting_gunshots_subset.tfrecord') #, 1-CV_frac, 1)
rec_len = 22832 
lr_h = lr_model.fit_generator(train_gen,steps_per_epoch=int(rec_len*(1-CV_frac))//batch_size, epochs=50,validation_data=val_gen, validation_steps=int(rec_len*CV_frac)//20,verbose=0, callbacks=[TQDMNotebookCallback()])
# Out:
# WARNING:tensorflow:From /Users/abhilash/anaconda3/envs/avacado/lib/python3.7/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# HBox(children=(IntProgress(value=0, description='Training', max=50, style=ProgressStyle(description_width='ini…
# HBox(children=(IntProgress(value=0, description='Epoch 0', max=513, style=ProgressStyle(description_width='ini…
# WARNING:tensorflow:From <ipython-input-2-90491d052665>:13: tf_record_iterator (from tensorflow.python.lib.io.tf_record) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use eager execution and:
# `tf.data.TFRecordDataset(path)`
# After fractioning:
# After fractioning:
# HBox(children=(IntProgress(value=0, description='Epoch 1', max=513, style=ProgressStyle(description_width='ini…
# HBox(children=(IntProgress(value=0, description='Epoch 2', max=513, style=ProgressStyle(description_width='ini…
# HBox(children=(IntProgress(value=0, description='Epoch 3', max=513, style=ProgressStyle(description_width='ini…
# HBox(children=(IntProgress(value=0, description='Epoch 4', max=513, style=ProgressStyle(description_width='ini…
# HBox(children=(IntProgress(value=0, description='Epoch 5', max=513, style=ProgressStyle(description_width='ini…
# HBox(children=(IntProgress(value=0, description='Epoch 6', max=513, style=ProgressStyle(description_width='ini…
# HBox(children=(IntProgress(value=0, description='Epoch 7', max=513, style=ProgressStyle(description_width='ini…
# HBox(children=(IntProgress(value=0, description='Epoch 8', max=513, style=ProgressStyle(description_width='ini…
# HBox(children=(IntProgress(value=0, description='Epoch 9', max=513, style=ProgressStyle(description_width='ini…
# HBox(children=(IntProgress(value=0, description='Epoch 10', max=513, style=ProgressStyle(description_width='in…
# HBox(children=(IntProgress(value=0, description='Epoch 11', max=513, style=ProgressStyle(description_width='in…
# HBox(children=(IntProgress(value=0, description='Epoch 12', max=513, style=ProgressStyle(description_width='in…
# HBox(children=(IntProgress(value=0, description='Epoch 13', max=513, style=ProgressStyle(description_width='in…
# HBox(children=(IntProgress(value=0, description='Epoch 14', max=513, style=ProgressStyle(description_width='in…
# HBox(children=(IntProgress(value=0, description='Epoch 15', max=513, style=ProgressStyle(description_width='in…
# HBox(children=(IntProgress(value=0, description='Epoch 16', max=513, style=ProgressStyle(description_width='in…
# HBox(children=(IntProgress(value=0, description='Epoch 17', max=513, style=ProgressStyle(description_width='in…
# HBox(children=(IntProgress(value=0, description='Epoch 18', max=513, style=ProgressStyle(description_width='in…
# HBox(children=(IntProgress(value=0, description='Epoch 19', max=513, style=ProgressStyle(description_width='in…
# HBox(children=(IntProgress(value=0, description='Epoch 20', max=513, style=ProgressStyle(description_width='in…
# HBox(children=(IntProgress(value=0, description='Epoch 21', max=513, style=ProgressStyle(description_width='in…
# HBox(children=(IntProgress(value=0, description='Epoch 22', max=513, style=ProgressStyle(description_width='in…
# HBox(children=(IntProgress(value=0, description='Epoch 23', max=513, style=ProgressStyle(description_width='in…
# HBox(children=(IntProgress(value=0, description='Epoch 24', max=513, style=ProgressStyle(description_width='in…
# HBox(children=(IntProgress(value=0, description='Epoch 25', max=513, style=ProgressStyle(description_width='in…
# HBox(children=(IntProgress(value=0, description='Epoch 26', max=513, style=ProgressStyle(description_width='in…
# HBox(children=(IntProgress(value=0, description='Epoch 27', max=513, style=ProgressStyle(description_width='in…
# HBox(children=(IntProgress(value=0, description='Epoch 28', max=513, style=ProgressStyle(description_width='in…
# HBox(children=(IntProgress(value=0, description='Epoch 29', max=513, style=ProgressStyle(description_width='in…
# HBox(children=(IntProgress(value=0, description='Epoch 30', max=513, style=ProgressStyle(description_width='in…
# HBox(children=(IntProgress(value=0, description='Epoch 31', max=513, style=ProgressStyle(description_width='in…
# HBox(children=(IntProgress(value=0, description='Epoch 32', max=513, style=ProgressStyle(description_width='in…
# HBox(children=(IntProgress(value=0, description='Epoch 33', max=513, style=ProgressStyle(description_width='in…
# HBox(children=(IntProgress(value=0, description='Epoch 34', max=513, style=ProgressStyle(description_width='in…
# HBox(children=(IntProgress(value=0, description='Epoch 35', max=513, style=ProgressStyle(description_width='in…
# HBox(children=(IntProgress(value=0, description='Epoch 36', max=513, style=ProgressStyle(description_width='in…
# HBox(children=(IntProgress(value=0, description='Epoch 37', max=513, style=ProgressStyle(description_width='in…
# HBox(children=(IntProgress(value=0, description='Epoch 38', max=513, style=ProgressStyle(description_width='in…
# HBox(children=(IntProgress(value=0, description='Epoch 39', max=513, style=ProgressStyle(description_width='in…
# HBox(children=(IntProgress(value=0, description='Epoch 40', max=513, style=ProgressStyle(description_width='in…
# HBox(children=(IntProgress(value=0, description='Epoch 41', max=513, style=ProgressStyle(description_width='in…
# HBox(children=(IntProgress(value=0, description='Epoch 42', max=513, style=ProgressStyle(description_width='in…
# HBox(children=(IntProgress(value=0, description='Epoch 43', max=513, style=ProgressStyle(description_width='in…
# HBox(children=(IntProgress(value=0, description='Epoch 44', max=513, style=ProgressStyle(description_width='in…
# HBox(children=(IntProgress(value=0, description='Epoch 45', max=513, style=ProgressStyle(description_width='in…
# HBox(children=(IntProgress(value=0, description='Epoch 46', max=513, style=ProgressStyle(description_width='in…
# HBox(children=(IntProgress(value=0, description='Epoch 47', max=513, style=ProgressStyle(description_width='in…
# HBox(children=(IntProgress(value=0, description='Epoch 48', max=513, style=ProgressStyle(description_width='in…
# HBox(children=(IntProgress(value=0, description='Epoch 49', max=513, style=ProgressStyle(description_width='in…

# %%
plt.plot(lr_h.history['acc'], 'o-', label='train_acc')
plt.plot(lr_h.history['val_acc'], 'x-', label='val_acc')
plt.xlabel('Epochs(50)', size=18)
plt.ylabel('Accuracy', size=18)
plt.legend()
plt.savefig('results/training_results/LogisticRegression_BinaryCE_Adam_pochs50.png', dpi = 300)

# %%
print("Epochs = 100")
print("val_loss length:",len(lr_h.history['val_loss']))
print("val_acc length:",len(lr_h.history['val_acc']))
print("loss length:",len(lr_h.history['loss']))
print("acc length:",len(lr_h.history['acc']))

print("Average Training loss =", sum(lr_h.history['loss'])/len(lr_h.history['loss']))
print("Average Training accuracy=", sum(lr_h.history['acc'])/len(lr_h.history['acc'])*100)
print("Average validation loss =", sum(lr_h.history['val_loss'])/len(lr_h.history['val_loss']))
print("Average validation accuracy=", sum(lr_h.history['val_acc'])/len(lr_h.history['val_acc'])*100)


from keras.utils import plot_model
plot_model(lr_model, to_file='results/training_results/model_LogisticRegression_BinaryCE_Adam.png')
# Out:
# Epochs = 100
# val_loss length: 50
# val_acc length: 50
# loss length: 50
# acc length: 50
# Average Training loss = 0.005123378223686259
# Average Training accuracy= 99.83011700976894
# Average validation loss = 0.4298901626815815
# Average validation accuracy= 96.93420979537461

# %%
lr_model.save('Models/LogisticRegression_BinaryCE_Adam_50Epochs.h5')

# %%
# Single Layer Neural Network: 1 Hidden Layer with Relu Activation with batch normalization

# %%
from keras.models import Sequential
from keras.layers import Dense, BatchNormalization, Flatten

nn_model = Sequential()
nn_model.add(BatchNormalization(input_shape=(10, 128)))
nn_model.add(Flatten())
nn_model.add(Dense(100, activation='relu'))
nn_model.add(Dense(1, activation='sigmoid'))                 
nn_model.compile(loss='binary_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

# %%
batch_size=  40 
CV_frac = 0.1
train_gen = data_generator(batch_size,'../data/preprocessed/unbaltrain_spotting_gunshots_subset.tfrecord') #, 0, 1-CV_frac)
val_gen = data_generator(20,'../data/preprocessed/eval_spotting_gunshots_subset.tfrecord') #, 1-CV_frac, 1)
rec_len = 22832 
nn_h = nn_model.fit_generator(train_gen,steps_per_epoch=int(rec_len*(1-CV_frac))//batch_size, epochs=100,validation_data=val_gen, validation_steps=int(rec_len*CV_frac)//20,verbose=0, callbacks=[TQDMNotebookCallback()])
# Out:
# HBox(children=(IntProgress(value=0, description='Training', style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='Epoch 0', max=513, style=ProgressStyle(description_width='ini…
# After fractioning:
# After fractioning:
# HBox(children=(IntProgress(value=0, description='Epoch 1', max=513, style=ProgressStyle(description_width='ini…
# HBox(children=(IntProgress(value=0, description='Epoch 2', max=513, style=ProgressStyle(description_width='ini…
# HBox(children=(IntProgress(value=0, description='Epoch 3', max=513, style=ProgressStyle(description_width='ini…
# HBox(children=(IntProgress(value=0, description='Epoch 4', max=513, style=ProgressStyle(description_width='ini…
# HBox(children=(IntProgress(value=0, description='Epoch 5', max=513, style=ProgressStyle(description_width='ini…
# HBox(children=(IntProgress(value=0, description='Epoch 6', max=513, style=ProgressStyle(description_width='ini…
# HBox(children=(IntProgress(value=0, description='Epoch 7', max=513, style=ProgressStyle(description_width='ini…
# HBox(children=(IntProgress(value=0, description='Epoch 8', max=513, style=ProgressStyle(description_width='ini…
# HBox(children=(IntProgress(value=0, description='Epoch 9', max=513, style=ProgressStyle(description_width='ini…
# HBox(children=(IntProgress(value=0, description='Epoch 10', max=513, style=ProgressStyle(description_width='in…
# HBox(children=(IntProgress(value=0, description='Epoch 11', max=513, style=ProgressStyle(description_width='in…
# HBox(children=(IntProgress(value=0, description='Epoch 12', max=513, style=ProgressStyle(description_width='in…
# HBox(children=(IntProgress(value=0, description='Epoch 13', max=513, style=ProgressStyle(description_width='in…
# HBox(children=(IntProgress(value=0, description='Epoch 14', max=513, style=ProgressStyle(description_width='in…
# HBox(children=(IntProgress(value=0, description='Epoch 15', max=513, style=ProgressStyle(description_width='in…
# HBox(children=(IntProgress(value=0, description='Epoch 16', max=513, style=ProgressStyle(description_width='in…
# HBox(children=(IntProgress(value=0, description='Epoch 17', max=513, style=ProgressStyle(description_width='in…
# HBox(children=(IntProgress(value=0, description='Epoch 18', max=513, style=ProgressStyle(description_width='in…
# HBox(children=(IntProgress(value=0, description='Epoch 19', max=513, style=ProgressStyle(description_width='in…
# HBox(children=(IntProgress(value=0, description='Epoch 20', max=513, style=ProgressStyle(description_width='in…
# HBox(children=(IntProgress(value=0, description='Epoch 21', max=513, style=ProgressStyle(description_width='in…
# HBox(children=(IntProgress(value=0, description='Epoch 22', max=513, style=ProgressStyle(description_width='in…
# HBox(children=(IntProgress(value=0, description='Epoch 23', max=513, style=ProgressStyle(description_width='in…
# HBox(children=(IntProgress(value=0, description='Epoch 24', max=513, style=ProgressStyle(description_width='in…
# HBox(children=(IntProgress(value=0, description='Epoch 25', max=513, style=ProgressStyle(description_width='in…
# HBox(children=(IntProgress(value=0, description='Epoch 26', max=513, style=ProgressStyle(description_width='in…
# HBox(children=(IntProgress(value=0, description='Epoch 27', max=513, style=ProgressStyle(description_width='in…
# HBox(children=(IntProgress(value=0, description='Epoch 28', max=513, style=ProgressStyle(description_width='in…
# HBox(children=(IntProgress(value=0, description='Epoch 29', max=513, style=ProgressStyle(description_width='in…
# HBox(children=(IntProgress(value=0, description='Epoch 30', max=513, style=ProgressStyle(description_width='in…
# HBox(children=(IntProgress(value=0, description='Epoch 31', max=513, style=ProgressStyle(description_width='in…
# HBox(children=(IntProgress(value=0, description='Epoch 32', max=513, style=ProgressStyle(description_width='in…
# HBox(children=(IntProgress(value=0, description='Epoch 33', max=513, style=ProgressStyle(description_width='in…
# HBox(children=(IntProgress(value=0, description='Epoch 34', max=513, style=ProgressStyle(description_width='in…
# HBox(children=(IntProgress(value=0, description='Epoch 35', max=513, style=ProgressStyle(description_width='in…
# HBox(children=(IntProgress(value=0, description='Epoch 36', max=513, style=ProgressStyle(description_width='in…
# HBox(children=(IntProgress(value=0, description='Epoch 37', max=513, style=ProgressStyle(description_width='in…
# HBox(children=(IntProgress(value=0, description='Epoch 38', max=513, style=ProgressStyle(description_width='in…
# HBox(children=(IntProgress(value=0, description='Epoch 39', max=513, style=ProgressStyle(description_width='in…
# HBox(children=(IntProgress(value=0, description='Epoch 40', max=513, style=ProgressStyle(description_width='in…
# HBox(children=(IntProgress(value=0, description='Epoch 41', max=513, style=ProgressStyle(description_width='in…
# HBox(children=(IntProgress(value=0, description='Epoch 42', max=513, style=ProgressStyle(description_width='in…
# HBox(children=(IntProgress(value=0, description='Epoch 43', max=513, style=ProgressStyle(description_width='in…
# HBox(children=(IntProgress(value=0, description='Epoch 44', max=513, style=ProgressStyle(description_width='in…
# HBox(children=(IntProgress(value=0, description='Epoch 45', max=513, style=ProgressStyle(description_width='in…
# HBox(children=(IntProgress(value=0, description='Epoch 46', max=513, style=ProgressStyle(description_width='in…
# HBox(children=(IntProgress(value=0, description='Epoch 47', max=513, style=ProgressStyle(description_width='in…
# HBox(children=(IntProgress(value=0, description='Epoch 48', max=513, style=ProgressStyle(description_width='in…
# HBox(children=(IntProgress(value=0, description='Epoch 49', max=513, style=ProgressStyle(description_width='in…
# HBox(children=(IntProgress(value=0, description='Epoch 50', max=513, style=ProgressStyle(description_width='in…
# HBox(children=(IntProgress(value=0, description='Epoch 51', max=513, style=ProgressStyle(description_width='in…
# HBox(children=(IntProgress(value=0, description='Epoch 52', max=513, style=ProgressStyle(description_width='in…
# HBox(children=(IntProgress(value=0, description='Epoch 53', max=513, style=ProgressStyle(description_width='in…
# HBox(children=(IntProgress(value=0, description='Epoch 54', max=513, style=ProgressStyle(description_width='in…
# HBox(children=(IntProgress(value=0, description='Epoch 55', max=513, style=ProgressStyle(description_width='in…
# HBox(children=(IntProgress(value=0, description='Epoch 56', max=513, style=ProgressStyle(description_width='in…
# HBox(children=(IntProgress(value=0, description='Epoch 57', max=513, style=ProgressStyle(description_width='in…
# HBox(children=(IntProgress(value=0, description='Epoch 58', max=513, style=ProgressStyle(description_width='in…
# HBox(children=(IntProgress(value=0, description='Epoch 59', max=513, style=ProgressStyle(description_width='in…
# HBox(children=(IntProgress(value=0, description='Epoch 60', max=513, style=ProgressStyle(description_width='in…
# HBox(children=(IntProgress(value=0, description='Epoch 61', max=513, style=ProgressStyle(description_width='in…
# HBox(children=(IntProgress(value=0, description='Epoch 62', max=513, style=ProgressStyle(description_width='in…
# HBox(children=(IntProgress(value=0, description='Epoch 63', max=513, style=ProgressStyle(description_width='in…
# HBox(children=(IntProgress(value=0, description='Epoch 64', max=513, style=ProgressStyle(description_width='in…
# HBox(children=(IntProgress(value=0, description='Epoch 65', max=513, style=ProgressStyle(description_width='in…
# HBox(children=(IntProgress(value=0, description='Epoch 66', max=513, style=ProgressStyle(description_width='in…
# HBox(children=(IntProgress(value=0, description='Epoch 67', max=513, style=ProgressStyle(description_width='in…
# HBox(children=(IntProgress(value=0, description='Epoch 68', max=513, style=ProgressStyle(description_width='in…
# HBox(children=(IntProgress(value=0, description='Epoch 69', max=513, style=ProgressStyle(description_width='in…
# HBox(children=(IntProgress(value=0, description='Epoch 70', max=513, style=ProgressStyle(description_width='in…
# HBox(children=(IntProgress(value=0, description='Epoch 71', max=513, style=ProgressStyle(description_width='in…
# HBox(children=(IntProgress(value=0, description='Epoch 72', max=513, style=ProgressStyle(description_width='in…
# HBox(children=(IntProgress(value=0, description='Epoch 73', max=513, style=ProgressStyle(description_width='in…
# HBox(children=(IntProgress(value=0, description='Epoch 74', max=513, style=ProgressStyle(description_width='in…
# HBox(children=(IntProgress(value=0, description='Epoch 75', max=513, style=ProgressStyle(description_width='in…
# HBox(children=(IntProgress(value=0, description='Epoch 76', max=513, style=ProgressStyle(description_width='in…
# HBox(children=(IntProgress(value=0, description='Epoch 77', max=513, style=ProgressStyle(description_width='in…
# HBox(children=(IntProgress(value=0, description='Epoch 78', max=513, style=ProgressStyle(description_width='in…
# HBox(children=(IntProgress(value=0, description='Epoch 79', max=513, style=ProgressStyle(description_width='in…
# HBox(children=(IntProgress(value=0, description='Epoch 80', max=513, style=ProgressStyle(description_width='in…
# HBox(children=(IntProgress(value=0, description='Epoch 81', max=513, style=ProgressStyle(description_width='in…
# HBox(children=(IntProgress(value=0, description='Epoch 82', max=513, style=ProgressStyle(description_width='in…
# HBox(children=(IntProgress(value=0, description='Epoch 83', max=513, style=ProgressStyle(description_width='in…
# HBox(children=(IntProgress(value=0, description='Epoch 84', max=513, style=ProgressStyle(description_width='in…
# HBox(children=(IntProgress(value=0, description='Epoch 85', max=513, style=ProgressStyle(description_width='in…
# HBox(children=(IntProgress(value=0, description='Epoch 86', max=513, style=ProgressStyle(description_width='in…
# HBox(children=(IntProgress(value=0, description='Epoch 87', max=513, style=ProgressStyle(description_width='in…
# HBox(children=(IntProgress(value=0, description='Epoch 88', max=513, style=ProgressStyle(description_width='in…
# HBox(children=(IntProgress(value=0, description='Epoch 89', max=513, style=ProgressStyle(description_width='in…
# HBox(children=(IntProgress(value=0, description='Epoch 90', max=513, style=ProgressStyle(description_width='in…
# HBox(children=(IntProgress(value=0, description='Epoch 91', max=513, style=ProgressStyle(description_width='in…
# HBox(children=(IntProgress(value=0, description='Epoch 92', max=513, style=ProgressStyle(description_width='in…
# HBox(children=(IntProgress(value=0, description='Epoch 93', max=513, style=ProgressStyle(description_width='in…
# HBox(children=(IntProgress(value=0, description='Epoch 94', max=513, style=ProgressStyle(description_width='in…
# HBox(children=(IntProgress(value=0, description='Epoch 95', max=513, style=ProgressStyle(description_width='in…
# HBox(children=(IntProgress(value=0, description='Epoch 96', max=513, style=ProgressStyle(description_width='in…
# HBox(children=(IntProgress(value=0, description='Epoch 97', max=513, style=ProgressStyle(description_width='in…
# HBox(children=(IntProgress(value=0, description='Epoch 98', max=513, style=ProgressStyle(description_width='in…
# HBox(children=(IntProgress(value=0, description='Epoch 99', max=513, style=ProgressStyle(description_width='in…

# %%
plt.plot(nn_h.history['acc'], 'o-', label='train_acc')
plt.plot(nn_h.history['val_acc'], 'x-', label='val_acc')
plt.xlabel('Epochs(100)', size=18)
plt.ylabel('Accuracy', size=18)
plt.legend()
plt.savefig('results/training_results/SingleLayerNN__Loss=BinaryCE_100Epochs.png', dpi = 300)

# %%
print("Epochs = 100")
print("val_loss length:",len(nn_h.history['val_loss']))
print("val_acc length:",len(nn_h.history['val_acc']))
print("loss length:",len(nn_h.history['loss']))
print("acc length:",len(nn_h.history['acc']))

print("Average Training loss =", sum(nn_h.history['loss'])/len(nn_h.history['loss']))
print("Average Training accuracy=", sum(nn_h.history['acc'])/len(nn_h.history['acc'])*100)
print("Average validation loss =", sum(nn_h.history['val_loss'])/len(nn_h.history['val_loss']))
print("Average validation accuracy=", sum(nn_h.history['val_acc'])/len(nn_h.history['val_acc'])*100)


from keras.utils import plot_model
plot_model(nn_model, to_file='results/training_results/SingleLayerNN__Loss=BinaryCE_100Epochs.png')
# Out:
# Epochs = 100
# val_loss length: 100
# val_acc length: 100
# loss length: 100
# acc length: 100
# Average Training loss = 0.000592074951090739
# Average Training accuracy= 99.98187135035067
# Average validation loss = 0.4739131328484082
# Average validation accuracy= 96.9276308464376

# %%
nn_model.save('Models/SingleLayerNN__Loss=BinaryCE_100Epochs.h5')

# %%
## Single Layer NN Model with Mean Squared Logarithmic Error

# %%
from keras.models import Sequential
from keras.layers import Dense, BatchNormalization, Flatten

nn_model = Sequential()
nn_model.add(BatchNormalization(input_shape=(10, 128)))
nn_model.add(Flatten())
nn_model.add(Dense(100, activation='relu'))
nn_model.add(Dense(1, activation='sigmoid'))                 
nn_model.compile(loss='mean_squared_logarithmic_error',
              optimizer='adam',
              metrics=['accuracy'])

# %%
## Multiclass Logistic Regression

# %%
from bitstring import BitArray  #To perform bit manipulation
from keras.preprocessing.sequence import pad_sequences

def data_generator_multiclass(batch_size, tfrecord, start_frac=0, end_frac=1):
    '''
    Shuffles the Audioset training data and returns a generator of training data and boolean laughter labels
    batch_size: batch size for each set of training data and labels
    tfrecord: filestring of the tfrecord file to train on
    start_frac: the starting point of the data set to use, as a fraction of total record length (used for CV)
    end_frac: the ending point of the data set to use, as a fraction of total record length (used for CV)
    '''
    max_len=10
    #tfrecord holds data in binary sequence string. 
    records = list(tf.python_io.tf_record_iterator(tfrecord))  #records holds the array of the tfrecord file
    if(tfrecord == '../data/preprocessed/unbaltrain_spotting_gunshots_subset.tfrecord'):
        print("Total audioframes in training dataset:", len(records))
    elif(tfrecord == '../data/preprocessed/eval_spotting_gunshots_subset.tfrecord'):
        print("Total audioframes in eval dataset:", len(records))
        
    records = records[int(start_frac*len(records)):int(end_frac*len(records))]  # Make train_set & CV_set 
    print("After fractioning:")
    if(tfrecord == '../data/preprocessed/unbaltrain_spotting_gunshots_subset.tfrecord'):
        print("Total audioframes in training dataset:", len(records))
    elif(tfrecord == '../data/preprocessed/eval_spotting_gunshots_subset.tfrecord'):
        print("Total audioframes in eval dataset:", len(records))
    
    rec_len = len(records)  # this is your train set, rest is CV_set
    shuffle = np.random.permutation(range(rec_len))
    num_batches = rec_len//batch_size - 1                      
    j = 0
    
    
    classes = ["gun","firework","background", "other"]
    dict_classes = dict.fromkeys(classes)
    
    gun_labels = [426,427,428,429,430,431]
    fireworks_labels = [432,433,434]
    background_labels= [506,507,508,509,510,511,512,513,514,515,516,517,518,519,520,521,522,523,524,525,526]
    other_labels =[]
    
    while True:
        X = []
        y = []  #add g=[],f=[],b=[],other=[]
        
        for idx in shuffle[j*batch_size:(j+1)*batch_size]:
            example = records[idx]
            tf_seq_example = tf.train.SequenceExample.FromString(example)
            example_label = list(np.asarray(tf_seq_example.context.feature['labels'].int64_list.value))
            dict_classes = {
                "gun":int(any((True for x in example_label if x in gun_labels))),
                "firework":int(any((True for x in example_label if x in fireworks_labels))),
                "background":int(any(True for x in example_label if x in background_labels)),
                "other": 0
            }
            if (sum(dict_classes.values()) == 0):
#                 dict_classes["other"] = 1
                y.append(3)
            elif (sum(dict_classes.values()) >1):
                dict_classes  = dict.fromkeys(dict_classes, 0)
                continue;  # skip this iteration since the audioframe contains co-occurence of our classes 
            elif (sum(dict_classes.values()) == 1):
                if (dict_classes["gun"] == 1):
                    y.append(0)
                if (dict_classes["firework"] == 1):
                    y.append(1)
                if (dict_classes["background"] == 1):
                    y.append(2)
                if (dict_classes["other"] == 1):
                    y.append(3)
                                
            n_frames = len(tf_seq_example.feature_lists.feature_list['audio_embedding'].feature)
            audio_frame = []
            for i in range(n_frames):
                audio_frame.append(np.frombuffer(tf_seq_example.feature_lists.feature_list['audio_embedding'].
                                                         feature[i].bytes_list.value[0],np.uint8).astype(np.float32)) # audio_frame gets 128 8 bit numbers on each for loop iteration
            pad = [np.zeros([128], np.float32) for i in range(max_len-n_frames)] 
            # if clip is less than 10 sec, audio_frame is padded with zeros for 
            #rest of the secs to make it to 10 sec.
            
            audio_frame += pad
            X.append(audio_frame) #eg: X[5] will output 5th audioframe 

        j += 1
        if j >= num_batches:
            shuffle = np.random.permutation(range(rec_len))
            j = 0

        X = np.array(X)
        print("size of X",len(X))
        print("size of y",len(y))
        yield X, np.array(y)

# %%
from keras.models import Sequential
from keras.layers import Dense, BatchNormalization, Flatten

multi_lr_model = Sequential()
# lr_model.add(Flatten(input_shape = (10,128)))
# multi_lr_model.add(BatchNormalization(input_shape=(10, 128)))

multi_lr_model.add(Flatten(input_shape=(10, 128)))
#multi_lr_model.add(Flatten())
multi_lr_model.add(Dense(4, activation='softmax'))                
multi_lr_model.compile(loss = 'sparse_categorical_crossentropy',
              optimizer='sgd',
              metrics=['accuracy'])

# %%
batch_size=  40 
CV_frac = 0.1
train_gen = data_generator_multiclass(batch_size,'../data/preprocessed/unbaltrain_spotting_gunshots_subset.tfrecord')#, 0, 1-CV_frac)
val_gen = data_generator_multiclass(20,'../data/preprocessed/eval_spotting_gunshots_subset.tfrecord')#, 1-CV_frac, 1)
rec_len = 22832 
multi_lr_h = multi_lr_model.fit_generator(train_gen,steps_per_epoch=int(rec_len*(1-CV_frac))//batch_size, epochs=50,validation_data=val_gen, validation_steps=int(rec_len*CV_frac)//20,verbose=0, callbacks=[TQDMNotebookCallback()])
# Out:
# HBox(children=(IntProgress(value=0, description='Training', max=50, style=ProgressStyle(description_width='ini…
# HBox(children=(IntProgress(value=0, description='Epoch 0', max=513, style=ProgressStyle(description_width='ini…
# Total audioframes in eval dataset: 645
# After fractioning:
# Total audioframes in eval dataset: 645
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 19
# size of y 19
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# Total audioframes in training dataset: 23385
# After fractioning:
# Total audioframes in training dataset: 23385
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 39
# size of y 39
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 39
# size of y 39
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 39
# size of y 39
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 39
# size of y 39
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 39
# size of y 39
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 39
# size of y 39
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 39
# size of y 39
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 39
# size of y 39
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 39
# size of y 39
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 39
# size of y 39
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 39
# size of y 39
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 39
# size of y 39
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 20
# size of y 20
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 39
# size of y 39
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 19
# size of y 19
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 19
# size of y 19
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 19
# size of y 19
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 19
# size of y 19
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 19
# size of y 19
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 19
# size of y 19
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 19
# size of y 19
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 19
# size of y 19
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 19
# size of y 19
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 19
# size of y 19
# HBox(children=(IntProgress(value=0, description='Epoch 1', max=513, style=ProgressStyle(description_width='ini…
# size of X 40
# size of y 40
# size of Xsize of X 40
# size of y 40
#  20
# size of y 20
# size of X 40
# size of y 40
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 39
# size of y 39
# size of X 20
# size of y 20
# size of X 40
# size of y 40
# size of X 19
# size of y 19
# size of X 20
# size of y 20
# size of X 40
# size of y 40
# size of X 20
# size of y 20
# size of X size of X40 20
# size of y 20
#
# size of y 40
# size of X 20
# size of y 20
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 39
# size of y 39
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 39
# size of y 39
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 39
# size of y 39
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 39
# size of y 39
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 39
# size of y 39
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 39
# size of y 39
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 39
# size of y 39
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 39
# size of y 39
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 39
# size of y 39
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 39
# size of y 39
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 39
# size of y 39
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 39
# size of y 39
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 39
# size of y 39
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 39
# size of y 39
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 39
# size of y 39
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 39
# size of y 39
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 20
# size of y 20
# size of X 18
# size of y 18
# size of X 40
# size of y 40
# size of X 20
# size of y 20
# size of X 40
# size of y 40
# size of X 20
# size of y 20
# size of X 40
# size of y 40
# size of X 20
# size of y 20
# size of X 40size of X
# size of y 40
#  20
# size of y 20
# size of Xsize of X 40
# size of y 40
#  20
# size of y 20
# size of X 20
# size of y 20
# size of X 40
# size of y 40
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 40
# size of y 40
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of Xsize of X 39
# size of y 20
# size of y 20
#  39
# size of X 20
# size of y 20
# size of X 40
# size of y 40
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 40
# size of y 40
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 19
# size of y 19
# size of X 20
# size of y 20
# size of X 19
# size of y 19
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 19
# size of y 19
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 19
# size of y 19
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 19
# size of y 19
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 19
# size of y 19
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 19
# size of y 19
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# HBox(children=(IntProgress(value=0, description='Epoch 2', max=513, style=ProgressStyle(description_width='ini…
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 20
# size of y 20
# size of X 40
# size of y 40
# size of X 19
# size of y 19size of X
#  40
# size of y 40
# size of X size of X 20
# size of y 20
# 40
# size of y 40
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 40
# size of y 40
# size of X 20
# size of y 20
# size of Xsize of X 20
# size of y 20
#  40
# size of y 40
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 39
# size of y 39
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 39
# size of y 39
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 39
# size of y 39
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 39
# size of y 39
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 39
# size of y 39
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 39
# size of y 39
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 39
# size of y 39
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 38
# size of y 38
# size of X 40
# size of y 40
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of Xsize of X 20
# size of y 20
#  40
# size of y 40
# size of X 20
# size of y 20
# size of X 19
# size of y 19
# size of X size of X40 20
# size of y 20
#
# size of y 40
# size of X 20
# size of y size of X20 39
# size of y 39
#
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 40
# size of y 40
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 40
# size of y 40
# size of X 20
# size of y 20
# size of X 40
# size of y 40
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of Xsize of X  20
# size of y 20
# 40
# size of y 40
# size of X 20
# size of y 20
# size of X 40
# size of y 40size of X
#  20
# size of y 20
# size of Xsize of X 40
# size of y 40
#  20
# size of y 20
# size of X 20
# size of y 20
# size of X 40
# size of y 40
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 19
# size of y 19
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 19
# size of y 19
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# ...
# size of y 40
#
# size of y 20
# size of X 19
# size of y 19
# size of X 40
# size of y 40
# size of X 20
# size of y 20
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 39
# size of y 39
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 39
# size of y 39
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 39
# size of y 39
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 39
# size of y 39
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 39
# size of y 39
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 39
# size of y 39
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 39
# size of y 39
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 39
# size of y 39
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 39
# size of y 39
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 39
# size of y 39
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 39
# size of y 39
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 39
# size of y 39
# size of X 39
# size of y 39
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 39
# size of y 39
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 20
# size of y 20size of X
#  40
# size of y 40
# size of X 20
# size of y 20
# size of X 40
# size of y 40
# size of X 20
# size of y 20
# size of X 40
# size of y 40
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 19
# size of y 19
# size of X 40
# size of y 40
# size of X 40
# size of y 40
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 19
# size of y 19
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 19
# size of y 19
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 19
# size of y 19
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 20size of X 40
# size of y 40
#
# size of y 20
# size of X 40
# size of y 40
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 40
# size of y 40
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 40
# size of y 40
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 40
# size of y 40
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X size of X40
# size of y 40
#  20
# size of y 20
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 19
# size of y 19
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 19
# size of y 19
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 19
# size of y 19
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 19
# size of y 19
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 18
# size of y 18
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 20
# size of y 20
# size of X 20
# size of y 20

# %%
plt.plot(multi_lr_h.history['acc'], 'o-', label='train_acc')
plt.plot(multi_lr_h.history['val_acc'], 'x-', label='val_acc')
plt.xlabel('Epochs(100)', size=18)
plt.ylabel('Accuracy', size=18)
plt.legend()
plt.savefig('results/training_results/LogisticRegression__Loss=sparse_catCE_100Epochs.png', dpi = 300)

# %%
print("Epochs = 100")
print("val_loss length:",len(multi_lr_h.history['val_loss']))
print("val_acc length:",len(multi_lr_h.history['val_acc']))
print("loss length:",len(multi_lr_h.history['loss']))
print("acc length:",len(multi_lr_h.history['acc']))

print("Average Training loss =", sum(multi_lr_h.history['loss'])/len(multi_lr_h.history['loss']))
print("Average Training accuracy=", sum(multi_lr_h.history['acc'])/len(multi_lr_h.history['acc'])*100)
print("Average validation loss =", sum(multi_lr_h.history['val_loss'])/len(multi_lr_h.history['val_loss']))
print("Average validation accuracy=", sum(multi_lr_h.history['val_acc'])/len(multi_lr_h.history['val_acc'])*100)


from keras.utils import plot_model
plot_model(multi_lr_model, to_file='results/training_results/LogisticRegression__Loss=sparse_catCE_100Epochs.png')
# Out:
# Epochs = 100
# val_loss length: 50
# val_acc length: 50
# loss length: 50
# acc length: 50
# Average Training loss = 1.6138023737530347
# Average Training accuracy= 89.9874738009425
# Average validation loss = 2.316181919113445
# Average validation accuracy= 85.62992906879433

# %%
multi_lr_model.save('Models/LogisticRegression__Loss=sparse_catCE_100Epochs.h5')

# %%
# from keras.models import Sequential
# from keras.layers import Dense, BatchNormalization, Dropout
# from keras.layers import LSTM
# from keras import regularizers

# lstm_model = Sequential()
# lstm_model.add(BatchNormalization(input_shape=(None, 128)))
# lstm_model.add(Dropout(0.5))
# lstm_model.add(LSTM(128, activation='relu',
#         kernel_regularizer=regularizers.l2(0.01),
#         activity_regularizer=regularizers.l2(0.01)))
# lstm_model.add(Dense(1, activation='sigmoid'))

# # try using different optimizers and different optimizer configs
# lstm_model.compile(loss='binary_crossentropy',
#               optimizer='adam',
#               metrics=['accuracy'])

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import tensorflow as tf
import glob

#!pip install seaborn
import seaborn as sns

# %%
labels = pd.read_csv('../data/raw/unbalanced_train_segments.csv',header=2, quotechar=r'"',skipinitialspace=True)
gunshot_labels = pd.read_csv('../data/raw/classes/gunshot_labels.csv',names=['num','label','description'])
print(gunshot_labels)
# Out:
#    num       label       description
# 0  426   /m/014zdl         Explosion
# 1  427   /m/032s66  Gunshot, gunfire
# 2  428    /m/04zjc       Machine gun
# 3  429  /m/02z32qm         Fusillade
# 4  430     /m/0_1c    Artillery fire
# 5  431   /m/073cg4           Cap gun

# %%
g_str = '|'.join(gunshot_labels['label'].values)
print(g_str)
# Out:
# /m/014zdl|/m/032s66|/m/04zjc|/m/02z32qm|/m/0_1c|/m/073cg4

# %%
#not_laugh_labels = pd.read_csv('human_non_laugh_labels.csv',names=['num','label','description'])
# l_str = '|'.join(laugh_labels['label'].values)
# In [ ]:
# n_str = '|'.join(not_laugh_labels['label'].values)
# labels['not_laughter'] = (labels['positive_labels'].str.contains(n_str) & ~labels['positive_labels'].str.contains(l_str))

# %%
firework_labels = pd.read_csv('../data/raw/classes/fireworks.csv', names = ['num', 'label', 'description'])

# %%
print(firework_labels)
# Out:
#    num        label  description
# 0  432     /m/0g6b5    Fireworks
# 1  433  /g/122z_qxw  Firecracker
# 2  434   /m/07qsvvw   Burst, pop

# %%
f_str = '|'.join(firework_labels['label'].values)

# %%
print(f_str)
# Out:
# /m/0g6b5|/g/122z_qxw|/m/07qsvvw

# %%
#Now that you have the f_str and g_str; check if each row in the unbalanced_train_segments.csv has a subset of 
#f_str or g_str string values. If yes, append 1 for that row else append 0 for that row.

# %%
background_labels = pd.read_csv('../data/raw/classes/background.csv', names = ['num', 'label', 'description'])
print(background_labels)
# Out:
#     num       label                 description
# 0   506  /t/dd00125          Inside, small room
# 1   507  /t/dd00126  Inside, large room or hall
# 2   508  /t/dd00127        Inside, public space
# 3   509  /t/dd00128   Outside, urban or manmade
# 4   510  /t/dd00129   Outside, rural or natural
# 5   511   /m/01b9nn               Reverberation
# 6   512   /m/01jnbd                        Echo
# 7   513   /m/096m7z                       Noise
# 8   514  /m/06_y0by         Environmental noise
# 9   515  /m/07rgkc5                      Static
# 10  516   /m/06xkwv                   Mains hum
# 11  517   /m/0g12c5                  Distortion
# 12  518   /m/08p9q4                    Sidetone
# 13  519  /m/07szfh9                   Cacophony
# 14  520    /m/0chx_                 White noise
# 15  521    /m/0cj0r                  Pink noise
# 16  522  /m/07p_0gm                   Throbbing
# 17  523   /m/01jwx6                   Vibration
# 18  524    /m/07c52                  Television
# 19  525    /m/06bz3                       Radio
# 20  526   /m/07hvw1             Field recording

# %%
b_str = '|'.join(background_labels['label'].values)

# %%
print(b_str)
# Out:
# /t/dd00125|/t/dd00126|/t/dd00127|/t/dd00128|/t/dd00129|/m/01b9nn|/m/01jnbd|/m/096m7z|/m/06_y0by|/m/07rgkc5|/m/06xkwv|/m/0g12c5|/m/08p9q4|/m/07szfh9|/m/0chx_|/m/0cj0r|/m/07p_0gm|/m/01jwx6|/m/07c52|/m/06bz3|/m/07hvw1

# %%
labels['fireworks'] = labels['positive_labels'].str.contains(f_str) & ~labels['positive_labels'].str.contains(g_str) & ~labels['positive_labels'].str.contains(b_str)

# %%
print(labels)
# Out:
#               # YTID  start_seconds  end_seconds  \
# 0        ---1_cCGK4M            0.0         10.0
# 1        ---2_BBVHAA           30.0         40.0
# 2        ---B_v8ZoBY           30.0         40.0
# 3        ---EDNidJUA           30.0         40.0
# 4        ---N4cFAE1A           21.0         31.0
# 5        ---fcVQUf3E           30.0         40.0
# 6        ---g9OGAhwc           30.0         40.0
# 7        ---lTs1dxhU           30.0         40.0
# 8        ---mO--kRQk           30.0         40.0
# 9        ---qub7uxgs           30.0         40.0
# 10       ---yQzzLcFU           30.0         40.0
# 11       --04kMEQOAs            0.0         10.0
# 12       --0AzKXCHj8           22.0         32.0
# 13       --0B3G_C3qc           10.0         20.0
# 14       --0CNhurbZE           30.0         40.0
# 15       --0F7kbzAMA           30.0         40.0
# 16       --0FMNFsVeg           30.0         40.0
# 17       --0MF9K5N30           30.0         40.0
# 18       --0Oh0JxzjQ           30.0         40.0
# 19       --0PQM4-hqg           30.0         40.0
# 20       --0XKTm28ts           50.0         60.0
# 21       --0_x3T5DQI           30.0         40.0
# 22       --0aJtOMp2M           30.0         40.0
# 23       --0bntG9i7E           30.0         40.0
# 24       --0fYwELbpk           30.0         40.0
# 25       --0fim4-6Ig           30.0         40.0
# 26       --0pVlB7mQ8           30.0         40.0
# 27       --0ukMG7yH4           30.0         40.0
# 28       --0vTxLiRuQ            4.0         14.0
# 29       --0w1YA1Hm4           30.0         40.0
# ...              ...            ...          ...
# 2041759  zzvtIpzFF9k           30.0         40.0
# 2041760  zzw7ibZwvAk           30.0         40.0
# 2041761  zzwBazlj0Oc           30.0         40.0
# 2041762  zzwBtLuYJX8          130.0        140.0
# 2041763  zzwEaUOXSZs           30.0         40.0
# 2041764  zzwbG0dHLhI          150.0        160.0
# 2041765  zzwkvzWKJxI           50.0         60.0
# 2041766  zzwp5Z2qZKU          180.0        190.0
# 2041767  zzwsSOcZVTs            0.0         10.0
# 2041768  zzx-lGzV5dE           30.0         40.0
# 2041769  zzxIF9qnNfc           40.0         50.0
# 2041770  zzxK96M3XVY          110.0        120.0
# 2041771  zzxSVJFyAuc           30.0         40.0
# 2041772  zzxUh44r4Wg           30.0         40.0
# 2041773  zzxXdFWb-LM           50.0         60.0
# 2041774  zzxfWc5U3Wk          430.0        440.0
# 2041775  zzxgeSP8f5Y            7.0         17.0
# 2041776  zzy2Lgtpc5o            0.0         10.0
# 2041777  zzyJtkvCgQ4           90.0        100.0
# 2041778  zzy_5evgl3Y           30.0         40.0
# 2041779  zzycbwlBJXQ          180.0        190.0
# 2041780  zzyiWF0F9sg           20.0         30.0
# 2041781  zzyjKSkzyys           30.0         40.0
# 2041782  zzyr6l8MetA           60.0         70.0
# 2041783  zzyxEu9a2hw            0.0         10.0
# 2041784  zzyyleHsxfk           20.0         30.0
# 2041785  zzz-JsGPtxQ          120.0        130.0
# 2041786  zzz3PZXRQ_8           30.0         40.0
# 2041787  zzznDcamMpw            0.0         10.0
# 2041788  zzztDPePp4g          410.0        420.0
#
#                                            positive_labels  fireworks
# 0        /m/01g50p,/m/0284vy3,/m/06d_3,/m/07jdr,/m/07rwm0c      False
# 1                                                 /m/09x0r      False
# 2                                                 /m/04rlf      False
# 3                    /m/02qldy,/m/02zsn,/m/05zppz,/m/09x0r      False
# 4                                        /m/04rlf,/m/09x0r      False
# 5                                        /m/019jd,/m/07yv9      False
# 6                                        /m/04rlf,/m/0c1dj      False
# 7                    /m/012f08,/m/07yv9,/m/0k4j,/t/dd00134      False
# 8                                                 /m/04rlf      False
# 9                                                 /m/09x0r      False
# 10                                              /t/dd00067      False
# 11                                       /m/06h7j,/m/09x0r      False
# 12                                                /m/04rlf      False
# 13                                                /m/09x0r      False
# 14                                                /m/09x0r      False
# 15                                                /m/09x0r      False
# 16                     /m/018vs,/m/0342h,/m/04rlf,/m/04szw      False
# 17                                                /m/09x0r      False
# 18                    /m/0342h,/m/04rlf,/m/04szw,/m/0fx80y      False
# 19                            /m/07swgks,/m/0j2kx,/m/0j6m2      False
# 20                                                /m/07yv9      False
# 21                                                /m/04rlf      False
# 22                                       /m/04rlf,/m/09x0r      False
# 23                                              /t/dd00004      False
# 24                                      /m/04rlf,/m/0ggx5q      False
# 25                    /m/0342h,/m/04rlf,/m/04szw,/m/0fx80y      False
# 26                                                /m/09x0r      False
# 27                                                /m/09x0r      False
# 28                                     /m/04rlf,/m/07s8j8t      False
# 29                              /m/01bjv,/m/07yv9,/m/09x0r      False
# ...                                                    ...        ...
# 2041759               /m/01g50p,/m/06d_3,/m/07jdr,/m/07yv9      False
# 2041760                                  /m/04rlf,/m/09x0r      False
# 2041761                       /m/015p6,/m/0h0rv,/t/dd00125      False
# 2041762     /m/01xqw,/m/04rlf,/m/04szw,/m/0ggq0m,/m/0l14_3      False
# 2041763                                            /m/0jbk      False
# 2041764                               /m/01yg9g,/t/dd00066      False
# 2041765                                         /t/dd00125      False
# 2041766                                  /m/04rlf,/m/0cfdd      False
# 2041767                       /m/07r04,/m/07yv9,/t/dd00129      False
# 2041768                       /m/03kmc9,/m/04qvtq,/m/04rlf      False
# 2041769                                /m/07yv9,/t/dd00129      False
# 2041770                                           /m/09x0r      False
# 2041771                         /m/01bjv,/m/07yv9,/m/09x0r      False
# 2041772                                           /m/09x0r      False
# 2041773                                           /m/09x0r      False
# 2041774                                /m/09x0r,/t/dd00125      False
# 2041775                                /m/07q2z82,/m/07yv9      False
# 2041776                         /m/04rlf,/m/09x0r,/m/0dls3      False
# 2041777                                /m/09x0r,/t/dd00088      False
# 2041778                                  /m/04rlf,/m/09x0r      False
# 2041779                                 /m/0164x2,/m/04rlf      False
# 2041780                                 /m/01j4z9,/m/0_ksk      False
# 2041781                                         /t/dd00038      False
# 2041782                                /m/04rlf,/m/05148p4      False
# 2041783                                  /m/07r04,/m/07yv9      False
# 2041784               /m/05tny_,/m/068hy,/m/0bt9lr,/m/0jbk      False
# 2041785                                /m/015lz1,/m/0l14jd      False
# 2041786                                 /m/030rvx,/m/09x0r      False
# 2041787                                  /m/09ddx,/m/09x0r      False
# 2041788                       /m/04rlf,/m/09x0r,/t/dd00126      False
#
# [2041789 rows x 5 columns]

# %%
labels['gunshots'] = labels['positive_labels'].str.contains(g_str) & ~labels['positive_labels'].str.contains(f_str) & ~labels['positive_labels'].str.contains(b_str)
print(labels)
# Out:
#               # YTID  start_seconds  end_seconds  \
# 0        ---1_cCGK4M            0.0         10.0
# 1        ---2_BBVHAA           30.0         40.0
# 2        ---B_v8ZoBY           30.0         40.0
# 3        ---EDNidJUA           30.0         40.0
# 4        ---N4cFAE1A           21.0         31.0
# 5        ---fcVQUf3E           30.0         40.0
# 6        ---g9OGAhwc           30.0         40.0
# 7        ---lTs1dxhU           30.0         40.0
# 8        ---mO--kRQk           30.0         40.0
# 9        ---qub7uxgs           30.0         40.0
# 10       ---yQzzLcFU           30.0         40.0
# 11       --04kMEQOAs            0.0         10.0
# 12       --0AzKXCHj8           22.0         32.0
# 13       --0B3G_C3qc           10.0         20.0
# 14       --0CNhurbZE           30.0         40.0
# 15       --0F7kbzAMA           30.0         40.0
# 16       --0FMNFsVeg           30.0         40.0
# 17       --0MF9K5N30           30.0         40.0
# 18       --0Oh0JxzjQ           30.0         40.0
# 19       --0PQM4-hqg           30.0         40.0
# 20       --0XKTm28ts           50.0         60.0
# 21       --0_x3T5DQI           30.0         40.0
# 22       --0aJtOMp2M           30.0         40.0
# 23       --0bntG9i7E           30.0         40.0
# 24       --0fYwELbpk           30.0         40.0
# 25       --0fim4-6Ig           30.0         40.0
# 26       --0pVlB7mQ8           30.0         40.0
# 27       --0ukMG7yH4           30.0         40.0
# 28       --0vTxLiRuQ            4.0         14.0
# 29       --0w1YA1Hm4           30.0         40.0
# ...              ...            ...          ...
# 2041759  zzvtIpzFF9k           30.0         40.0
# 2041760  zzw7ibZwvAk           30.0         40.0
# 2041761  zzwBazlj0Oc           30.0         40.0
# 2041762  zzwBtLuYJX8          130.0        140.0
# 2041763  zzwEaUOXSZs           30.0         40.0
# 2041764  zzwbG0dHLhI          150.0        160.0
# 2041765  zzwkvzWKJxI           50.0         60.0
# 2041766  zzwp5Z2qZKU          180.0        190.0
# 2041767  zzwsSOcZVTs            0.0         10.0
# 2041768  zzx-lGzV5dE           30.0         40.0
# 2041769  zzxIF9qnNfc           40.0         50.0
# 2041770  zzxK96M3XVY          110.0        120.0
# 2041771  zzxSVJFyAuc           30.0         40.0
# 2041772  zzxUh44r4Wg           30.0         40.0
# 2041773  zzxXdFWb-LM           50.0         60.0
# 2041774  zzxfWc5U3Wk          430.0        440.0
# 2041775  zzxgeSP8f5Y            7.0         17.0
# 2041776  zzy2Lgtpc5o            0.0         10.0
# 2041777  zzyJtkvCgQ4           90.0        100.0
# 2041778  zzy_5evgl3Y           30.0         40.0
# 2041779  zzycbwlBJXQ          180.0        190.0
# 2041780  zzyiWF0F9sg           20.0         30.0
# 2041781  zzyjKSkzyys           30.0         40.0
# 2041782  zzyr6l8MetA           60.0         70.0
# 2041783  zzyxEu9a2hw            0.0         10.0
# 2041784  zzyyleHsxfk           20.0         30.0
# 2041785  zzz-JsGPtxQ          120.0        130.0
# 2041786  zzz3PZXRQ_8           30.0         40.0
# 2041787  zzznDcamMpw            0.0         10.0
# 2041788  zzztDPePp4g          410.0        420.0
#
#                                            positive_labels  fireworks  \
# 0        /m/01g50p,/m/0284vy3,/m/06d_3,/m/07jdr,/m/07rwm0c      False
# 1                                                 /m/09x0r      False
# 2                                                 /m/04rlf      False
# 3                    /m/02qldy,/m/02zsn,/m/05zppz,/m/09x0r      False
# 4                                        /m/04rlf,/m/09x0r      False
# 5                                        /m/019jd,/m/07yv9      False
# 6                                        /m/04rlf,/m/0c1dj      False
# 7                    /m/012f08,/m/07yv9,/m/0k4j,/t/dd00134      False
# 8                                                 /m/04rlf      False
# 9                                                 /m/09x0r      False
# 10                                              /t/dd00067      False
# 11                                       /m/06h7j,/m/09x0r      False
# 12                                                /m/04rlf      False
# 13                                                /m/09x0r      False
# 14                                                /m/09x0r      False
# 15                                                /m/09x0r      False
# 16                     /m/018vs,/m/0342h,/m/04rlf,/m/04szw      False
# 17                                                /m/09x0r      False
# 18                    /m/0342h,/m/04rlf,/m/04szw,/m/0fx80y      False
# 19                            /m/07swgks,/m/0j2kx,/m/0j6m2      False
# 20                                                /m/07yv9      False
# 21                                                /m/04rlf      False
# 22                                       /m/04rlf,/m/09x0r      False
# 23                                              /t/dd00004      False
# 24                                      /m/04rlf,/m/0ggx5q      False
# 25                    /m/0342h,/m/04rlf,/m/04szw,/m/0fx80y      False
# 26                                                /m/09x0r      False
# 27                                                /m/09x0r      False
# 28                                     /m/04rlf,/m/07s8j8t      False
# 29                              /m/01bjv,/m/07yv9,/m/09x0r      False
# ...                                                    ...        ...
# 2041759               /m/01g50p,/m/06d_3,/m/07jdr,/m/07yv9      False
# 2041760                                  /m/04rlf,/m/09x0r      False
# 2041761                       /m/015p6,/m/0h0rv,/t/dd00125      False
# 2041762     /m/01xqw,/m/04rlf,/m/04szw,/m/0ggq0m,/m/0l14_3      False
# 2041763                                            /m/0jbk      False
# 2041764                               /m/01yg9g,/t/dd00066      False
# 2041765                                         /t/dd00125      False
# 2041766                                  /m/04rlf,/m/0cfdd      False
# 2041767                       /m/07r04,/m/07yv9,/t/dd00129      False
# 2041768                       /m/03kmc9,/m/04qvtq,/m/04rlf      False
# 2041769                                /m/07yv9,/t/dd00129      False
# 2041770                                           /m/09x0r      False
# 2041771                         /m/01bjv,/m/07yv9,/m/09x0r      False
# 2041772                                           /m/09x0r      False
# 2041773                                           /m/09x0r      False
# 2041774                                /m/09x0r,/t/dd00125      False
# 2041775                                /m/07q2z82,/m/07yv9      False
# 2041776                         /m/04rlf,/m/09x0r,/m/0dls3      False
# 2041777                                /m/09x0r,/t/dd00088      False
# 2041778                                  /m/04rlf,/m/09x0r      False
# 2041779                                 /m/0164x2,/m/04rlf      False
# 2041780                                 /m/01j4z9,/m/0_ksk      False
# 2041781                                         /t/dd00038      False
# 2041782                                /m/04rlf,/m/05148p4      False
# 2041783                                  /m/07r04,/m/07yv9      False
# 2041784               /m/05tny_,/m/068hy,/m/0bt9lr,/m/0jbk      False
# 2041785                                /m/015lz1,/m/0l14jd      False
# 2041786                                 /m/030rvx,/m/09x0r      False
# 2041787                                  /m/09ddx,/m/09x0r      False
# 2041788                       /m/04rlf,/m/09x0r,/t/dd00126      False
#
#          gunshots
# 0           False
# 1           False
# 2           False
# 3           False
# 4           False
# 5           False
# 6           False
# 7           False
# 8           False
# 9           False
# 10          False
# 11          False
# 12          False
# 13          False
# 14          False
# 15          False
# 16          False
# 17          False
# 18          False
# 19          False
# 20          False
# 21          False
# 22          False
# 23          False
# 24          False
# 25          False
# 26          False
# 27          False
# 28          False
# 29          False
# ...           ...
# 2041759     False
# 2041760     False
# 2041761     False
# 2041762     False
# 2041763     False
# 2041764     False
# 2041765     False
# 2041766     False
# 2041767     False
# 2041768     False
# 2041769     False
# 2041770     False
# 2041771     False
# 2041772     False
# 2041773     False
# 2041774     False
# 2041775     False
# 2041776     False
# 2041777     False
# 2041778     False
# 2041779     False
# 2041780     False
# 2041781     False
# 2041782     False
# 2041783     False
# 2041784     False
# 2041785     False
# 2041786     False
# 2041787     False
# 2041788     False
#
# [2041789 rows x 6 columns]

# %%
labels['background'] = labels['positive_labels'].str.contains(b_str) & ~labels['positive_labels'].str.contains(g_str) & ~labels['positive_labels'].str.contains(f_str)
print(labels)
# Out:
#               # YTID  start_seconds  end_seconds  \
# 0        ---1_cCGK4M            0.0         10.0
# 1        ---2_BBVHAA           30.0         40.0
# 2        ---B_v8ZoBY           30.0         40.0
# 3        ---EDNidJUA           30.0         40.0
# 4        ---N4cFAE1A           21.0         31.0
# 5        ---fcVQUf3E           30.0         40.0
# 6        ---g9OGAhwc           30.0         40.0
# 7        ---lTs1dxhU           30.0         40.0
# 8        ---mO--kRQk           30.0         40.0
# 9        ---qub7uxgs           30.0         40.0
# 10       ---yQzzLcFU           30.0         40.0
# 11       --04kMEQOAs            0.0         10.0
# 12       --0AzKXCHj8           22.0         32.0
# 13       --0B3G_C3qc           10.0         20.0
# 14       --0CNhurbZE           30.0         40.0
# 15       --0F7kbzAMA           30.0         40.0
# 16       --0FMNFsVeg           30.0         40.0
# 17       --0MF9K5N30           30.0         40.0
# 18       --0Oh0JxzjQ           30.0         40.0
# 19       --0PQM4-hqg           30.0         40.0
# 20       --0XKTm28ts           50.0         60.0
# 21       --0_x3T5DQI           30.0         40.0
# 22       --0aJtOMp2M           30.0         40.0
# 23       --0bntG9i7E           30.0         40.0
# 24       --0fYwELbpk           30.0         40.0
# 25       --0fim4-6Ig           30.0         40.0
# 26       --0pVlB7mQ8           30.0         40.0
# 27       --0ukMG7yH4           30.0         40.0
# 28       --0vTxLiRuQ            4.0         14.0
# 29       --0w1YA1Hm4           30.0         40.0
# ...              ...            ...          ...
# 2041759  zzvtIpzFF9k           30.0         40.0
# 2041760  zzw7ibZwvAk           30.0         40.0
# 2041761  zzwBazlj0Oc           30.0         40.0
# 2041762  zzwBtLuYJX8          130.0        140.0
# 2041763  zzwEaUOXSZs           30.0         40.0
# 2041764  zzwbG0dHLhI          150.0        160.0
# 2041765  zzwkvzWKJxI           50.0         60.0
# 2041766  zzwp5Z2qZKU          180.0        190.0
# 2041767  zzwsSOcZVTs            0.0         10.0
# 2041768  zzx-lGzV5dE           30.0         40.0
# 2041769  zzxIF9qnNfc           40.0         50.0
# 2041770  zzxK96M3XVY          110.0        120.0
# 2041771  zzxSVJFyAuc           30.0         40.0
# 2041772  zzxUh44r4Wg           30.0         40.0
# 2041773  zzxXdFWb-LM           50.0         60.0
# 2041774  zzxfWc5U3Wk          430.0        440.0
# 2041775  zzxgeSP8f5Y            7.0         17.0
# 2041776  zzy2Lgtpc5o            0.0         10.0
# 2041777  zzyJtkvCgQ4           90.0        100.0
# 2041778  zzy_5evgl3Y           30.0         40.0
# 2041779  zzycbwlBJXQ          180.0        190.0
# 2041780  zzyiWF0F9sg           20.0         30.0
# 2041781  zzyjKSkzyys           30.0         40.0
# 2041782  zzyr6l8MetA           60.0         70.0
# 2041783  zzyxEu9a2hw            0.0         10.0
# 2041784  zzyyleHsxfk           20.0         30.0
# 2041785  zzz-JsGPtxQ          120.0        130.0
# 2041786  zzz3PZXRQ_8           30.0         40.0
# 2041787  zzznDcamMpw            0.0         10.0
# 2041788  zzztDPePp4g          410.0        420.0
#
#                                            positive_labels  fireworks  \
# 0        /m/01g50p,/m/0284vy3,/m/06d_3,/m/07jdr,/m/07rwm0c      False
# 1                                                 /m/09x0r      False
# 2                                                 /m/04rlf      False
# 3                    /m/02qldy,/m/02zsn,/m/05zppz,/m/09x0r      False
# 4                                        /m/04rlf,/m/09x0r      False
# 5                                        /m/019jd,/m/07yv9      False
# 6                                        /m/04rlf,/m/0c1dj      False
# 7                    /m/012f08,/m/07yv9,/m/0k4j,/t/dd00134      False
# 8                                                 /m/04rlf      False
# 9                                                 /m/09x0r      False
# 10                                              /t/dd00067      False
# 11                                       /m/06h7j,/m/09x0r      False
# 12                                                /m/04rlf      False
# 13                                                /m/09x0r      False
# 14                                                /m/09x0r      False
# 15                                                /m/09x0r      False
# 16                     /m/018vs,/m/0342h,/m/04rlf,/m/04szw      False
# 17                                                /m/09x0r      False
# 18                    /m/0342h,/m/04rlf,/m/04szw,/m/0fx80y      False
# 19                            /m/07swgks,/m/0j2kx,/m/0j6m2      False
# 20                                                /m/07yv9      False
# 21                                                /m/04rlf      False
# 22                                       /m/04rlf,/m/09x0r      False
# 23                                              /t/dd00004      False
# 24                                      /m/04rlf,/m/0ggx5q      False
# 25                    /m/0342h,/m/04rlf,/m/04szw,/m/0fx80y      False
# 26                                                /m/09x0r      False
# 27                                                /m/09x0r      False
# 28                                     /m/04rlf,/m/07s8j8t      False
# 29                              /m/01bjv,/m/07yv9,/m/09x0r      False
# ...                                                    ...        ...
# 2041759               /m/01g50p,/m/06d_3,/m/07jdr,/m/07yv9      False
# 2041760                                  /m/04rlf,/m/09x0r      False
# 2041761                       /m/015p6,/m/0h0rv,/t/dd00125      False
# 2041762     /m/01xqw,/m/04rlf,/m/04szw,/m/0ggq0m,/m/0l14_3      False
# 2041763                                            /m/0jbk      False
# 2041764                               /m/01yg9g,/t/dd00066      False
# 2041765                                         /t/dd00125      False
# 2041766                                  /m/04rlf,/m/0cfdd      False
# 2041767                       /m/07r04,/m/07yv9,/t/dd00129      False
# 2041768                       /m/03kmc9,/m/04qvtq,/m/04rlf      False
# 2041769                                /m/07yv9,/t/dd00129      False
# 2041770                                           /m/09x0r      False
# 2041771                         /m/01bjv,/m/07yv9,/m/09x0r      False
# 2041772                                           /m/09x0r      False
# 2041773                                           /m/09x0r      False
# 2041774                                /m/09x0r,/t/dd00125      False
# 2041775                                /m/07q2z82,/m/07yv9      False
# 2041776                         /m/04rlf,/m/09x0r,/m/0dls3      False
# 2041777                                /m/09x0r,/t/dd00088      False
# 2041778                                  /m/04rlf,/m/09x0r      False
# 2041779                                 /m/0164x2,/m/04rlf      False
# 2041780                                 /m/01j4z9,/m/0_ksk      False
# 2041781                                         /t/dd00038      False
# 2041782                                /m/04rlf,/m/05148p4      False
# 2041783                                  /m/07r04,/m/07yv9      False
# 2041784               /m/05tny_,/m/068hy,/m/0bt9lr,/m/0jbk      False
# 2041785                                /m/015lz1,/m/0l14jd      False
# 2041786                                 /m/030rvx,/m/09x0r      False
# 2041787                                  /m/09ddx,/m/09x0r      False
# 2041788                       /m/04rlf,/m/09x0r,/t/dd00126      False
#
#          gunshots  background
# 0           False       False
# 1           False       False
# 2           False       False
# 3           False       False
# 4           False       False
# 5           False       False
# 6           False       False
# 7           False       False
# 8           False       False
# 9           False       False
# 10          False       False
# 11          False       False
# 12          False       False
# 13          False       False
# 14          False       False
# 15          False       False
# 16          False       False
# 17          False       False
# 18          False       False
# 19          False       False
# 20          False       False
# 21          False       False
# 22          False       False
# 23          False       False
# 24          False       False
# 25          False       False
# 26          False       False
# 27          False       False
# 28          False       False
# 29          False       False
# ...           ...         ...
# 2041759     False       False
# 2041760     False       False
# 2041761     False        True
# 2041762     False       False
# 2041763     False       False
# 2041764     False       False
# 2041765     False        True
# 2041766     False       False
# 2041767     False        True
# 2041768     False       False
# 2041769     False        True
# 2041770     False       False
# 2041771     False       False
# 2041772     False       False
# 2041773     False       False
# 2041774     False        True
# 2041775     False       False
# 2041776     False       False
# 2041777     False       False
# 2041778     False       False
# 2041779     False       False
# 2041780     False       False
# 2041781     False       False
# 2041782     False       False
# 2041783     False       False
# 2041784     False       False
# 2041785     False       False
# 2041786     False       False
# 2041787     False       False
# 2041788     False        True
#
# [2041789 rows x 7 columns]

# %%
labels['other'] = True
print(labels)
# Out:
#               # YTID  start_seconds  end_seconds  \
# 0        ---1_cCGK4M            0.0         10.0
# 1        ---2_BBVHAA           30.0         40.0
# 2        ---B_v8ZoBY           30.0         40.0
# 3        ---EDNidJUA           30.0         40.0
# 4        ---N4cFAE1A           21.0         31.0
# 5        ---fcVQUf3E           30.0         40.0
# 6        ---g9OGAhwc           30.0         40.0
# 7        ---lTs1dxhU           30.0         40.0
# 8        ---mO--kRQk           30.0         40.0
# 9        ---qub7uxgs           30.0         40.0
# 10       ---yQzzLcFU           30.0         40.0
# 11       --04kMEQOAs            0.0         10.0
# 12       --0AzKXCHj8           22.0         32.0
# 13       --0B3G_C3qc           10.0         20.0
# 14       --0CNhurbZE           30.0         40.0
# 15       --0F7kbzAMA           30.0         40.0
# 16       --0FMNFsVeg           30.0         40.0
# 17       --0MF9K5N30           30.0         40.0
# 18       --0Oh0JxzjQ           30.0         40.0
# 19       --0PQM4-hqg           30.0         40.0
# 20       --0XKTm28ts           50.0         60.0
# 21       --0_x3T5DQI           30.0         40.0
# 22       --0aJtOMp2M           30.0         40.0
# 23       --0bntG9i7E           30.0         40.0
# 24       --0fYwELbpk           30.0         40.0
# 25       --0fim4-6Ig           30.0         40.0
# 26       --0pVlB7mQ8           30.0         40.0
# 27       --0ukMG7yH4           30.0         40.0
# 28       --0vTxLiRuQ            4.0         14.0
# 29       --0w1YA1Hm4           30.0         40.0
# ...              ...            ...          ...
# 2041759  zzvtIpzFF9k           30.0         40.0
# 2041760  zzw7ibZwvAk           30.0         40.0
# 2041761  zzwBazlj0Oc           30.0         40.0
# 2041762  zzwBtLuYJX8          130.0        140.0
# 2041763  zzwEaUOXSZs           30.0         40.0
# 2041764  zzwbG0dHLhI          150.0        160.0
# 2041765  zzwkvzWKJxI           50.0         60.0
# 2041766  zzwp5Z2qZKU          180.0        190.0
# 2041767  zzwsSOcZVTs            0.0         10.0
# 2041768  zzx-lGzV5dE           30.0         40.0
# 2041769  zzxIF9qnNfc           40.0         50.0
# 2041770  zzxK96M3XVY          110.0        120.0
# 2041771  zzxSVJFyAuc           30.0         40.0
# 2041772  zzxUh44r4Wg           30.0         40.0
# 2041773  zzxXdFWb-LM           50.0         60.0
# 2041774  zzxfWc5U3Wk          430.0        440.0
# 2041775  zzxgeSP8f5Y            7.0         17.0
# 2041776  zzy2Lgtpc5o            0.0         10.0
# 2041777  zzyJtkvCgQ4           90.0        100.0
# 2041778  zzy_5evgl3Y           30.0         40.0
# 2041779  zzycbwlBJXQ          180.0        190.0
# 2041780  zzyiWF0F9sg           20.0         30.0
# 2041781  zzyjKSkzyys           30.0         40.0
# 2041782  zzyr6l8MetA           60.0         70.0
# 2041783  zzyxEu9a2hw            0.0         10.0
# 2041784  zzyyleHsxfk           20.0         30.0
# 2041785  zzz-JsGPtxQ          120.0        130.0
# 2041786  zzz3PZXRQ_8           30.0         40.0
# 2041787  zzznDcamMpw            0.0         10.0
# 2041788  zzztDPePp4g          410.0        420.0
#
#                                            positive_labels  fireworks  \
# 0        /m/01g50p,/m/0284vy3,/m/06d_3,/m/07jdr,/m/07rwm0c      False
# 1                                                 /m/09x0r      False
# 2                                                 /m/04rlf      False
# 3                    /m/02qldy,/m/02zsn,/m/05zppz,/m/09x0r      False
# 4                                        /m/04rlf,/m/09x0r      False
# 5                                        /m/019jd,/m/07yv9      False
# 6                                        /m/04rlf,/m/0c1dj      False
# 7                    /m/012f08,/m/07yv9,/m/0k4j,/t/dd00134      False
# 8                                                 /m/04rlf      False
# 9                                                 /m/09x0r      False
# 10                                              /t/dd00067      False
# 11                                       /m/06h7j,/m/09x0r      False
# 12                                                /m/04rlf      False
# 13                                                /m/09x0r      False
# 14                                                /m/09x0r      False
# 15                                                /m/09x0r      False
# 16                     /m/018vs,/m/0342h,/m/04rlf,/m/04szw      False
# 17                                                /m/09x0r      False
# 18                    /m/0342h,/m/04rlf,/m/04szw,/m/0fx80y      False
# 19                            /m/07swgks,/m/0j2kx,/m/0j6m2      False
# 20                                                /m/07yv9      False
# 21                                                /m/04rlf      False
# 22                                       /m/04rlf,/m/09x0r      False
# 23                                              /t/dd00004      False
# 24                                      /m/04rlf,/m/0ggx5q      False
# 25                    /m/0342h,/m/04rlf,/m/04szw,/m/0fx80y      False
# 26                                                /m/09x0r      False
# 27                                                /m/09x0r      False
# 28                                     /m/04rlf,/m/07s8j8t      False
# 29                              /m/01bjv,/m/07yv9,/m/09x0r      False
# ...                                                    ...        ...
# 2041759               /m/01g50p,/m/06d_3,/m/07jdr,/m/07yv9      False
# 2041760                                  /m/04rlf,/m/09x0r      False
# 2041761                       /m/015p6,/m/0h0rv,/t/dd00125      False
# 2041762     /m/01xqw,/m/04rlf,/m/04szw,/m/0ggq0m,/m/0l14_3      False
# 2041763                                            /m/0jbk      False
# 2041764                               /m/01yg9g,/t/dd00066      False
# 2041765                                         /t/dd00125      False
# 2041766                                  /m/04rlf,/m/0cfdd      False
# 2041767                       /m/07r04,/m/07yv9,/t/dd00129      False
# 2041768                       /m/03kmc9,/m/04qvtq,/m/04rlf      False
# 2041769                                /m/07yv9,/t/dd00129      False
# 2041770                                           /m/09x0r      False
# 2041771                         /m/01bjv,/m/07yv9,/m/09x0r      False
# 2041772                                           /m/09x0r      False
# 2041773                                           /m/09x0r      False
# 2041774                                /m/09x0r,/t/dd00125      False
# 2041775                                /m/07q2z82,/m/07yv9      False
# 2041776                         /m/04rlf,/m/09x0r,/m/0dls3      False
# 2041777                                /m/09x0r,/t/dd00088      False
# 2041778                                  /m/04rlf,/m/09x0r      False
# 2041779                                 /m/0164x2,/m/04rlf      False
# 2041780                                 /m/01j4z9,/m/0_ksk      False
# 2041781                                         /t/dd00038      False
# 2041782                                /m/04rlf,/m/05148p4      False
# 2041783                                  /m/07r04,/m/07yv9      False
# 2041784               /m/05tny_,/m/068hy,/m/0bt9lr,/m/0jbk      False
# 2041785                                /m/015lz1,/m/0l14jd      False
# 2041786                                 /m/030rvx,/m/09x0r      False
# 2041787                                  /m/09ddx,/m/09x0r      False
# 2041788                       /m/04rlf,/m/09x0r,/t/dd00126      False
#
#          gunshots  background  other
# 0           False       False   True
# 1           False       False   True
# 2           False       False   True
# 3           False       False   True
# 4           False       False   True
# 5           False       False   True
# 6           False       False   True
# 7           False       False   True
# 8           False       False   True
# 9           False       False   True
# 10          False       False   True
# 11          False       False   True
# 12          False       False   True
# 13          False       False   True
# 14          False       False   True
# 15          False       False   True
# 16          False       False   True
# 17          False       False   True
# 18          False       False   True
# 19          False       False   True
# 20          False       False   True
# 21          False       False   True
# 22          False       False   True
# 23          False       False   True
# 24          False       False   True
# 25          False       False   True
# 26          False       False   True
# 27          False       False   True
# 28          False       False   True
# 29          False       False   True
# ...           ...         ...    ...
# 2041759     False       False   True
# 2041760     False       False   True
# 2041761     False        True   True
# 2041762     False       False   True
# 2041763     False       False   True
# 2041764     False       False   True
# 2041765     False        True   True
# 2041766     False       False   True
# 2041767     False        True   True
# 2041768     False       False   True
# 2041769     False        True   True
# 2041770     False       False   True
# 2041771     False       False   True
# 2041772     False       False   True
# 2041773     False       False   True
# 2041774     False        True   True
# 2041775     False       False   True
# 2041776     False       False   True
# 2041777     False       False   True
# 2041778     False       False   True
# 2041779     False       False   True
# 2041780     False       False   True
# 2041781     False       False   True
# 2041782     False       False   True
# 2041783     False       False   True
# 2041784     False       False   True
# 2041785     False       False   True
# 2041786     False       False   True
# 2041787     False       False   True
# 2041788     False        True   True
#
# [2041789 rows x 8 columns]

# %%
labels['other'] = labels['other'] & ~labels['positive_labels'].str.contains(b_str) & ~labels['positive_labels'].str.contains(g_str) & ~labels['positive_labels'].str.contains(f_str)
print(labels)
# Out:
#               # YTID  start_seconds  end_seconds  \
# 0        ---1_cCGK4M            0.0         10.0
# 1        ---2_BBVHAA           30.0         40.0
# 2        ---B_v8ZoBY           30.0         40.0
# 3        ---EDNidJUA           30.0         40.0
# 4        ---N4cFAE1A           21.0         31.0
# 5        ---fcVQUf3E           30.0         40.0
# 6        ---g9OGAhwc           30.0         40.0
# 7        ---lTs1dxhU           30.0         40.0
# 8        ---mO--kRQk           30.0         40.0
# 9        ---qub7uxgs           30.0         40.0
# 10       ---yQzzLcFU           30.0         40.0
# 11       --04kMEQOAs            0.0         10.0
# 12       --0AzKXCHj8           22.0         32.0
# 13       --0B3G_C3qc           10.0         20.0
# 14       --0CNhurbZE           30.0         40.0
# 15       --0F7kbzAMA           30.0         40.0
# 16       --0FMNFsVeg           30.0         40.0
# 17       --0MF9K5N30           30.0         40.0
# 18       --0Oh0JxzjQ           30.0         40.0
# 19       --0PQM4-hqg           30.0         40.0
# 20       --0XKTm28ts           50.0         60.0
# 21       --0_x3T5DQI           30.0         40.0
# 22       --0aJtOMp2M           30.0         40.0
# 23       --0bntG9i7E           30.0         40.0
# 24       --0fYwELbpk           30.0         40.0
# 25       --0fim4-6Ig           30.0         40.0
# 26       --0pVlB7mQ8           30.0         40.0
# 27       --0ukMG7yH4           30.0         40.0
# 28       --0vTxLiRuQ            4.0         14.0
# 29       --0w1YA1Hm4           30.0         40.0
# ...              ...            ...          ...
# 2041759  zzvtIpzFF9k           30.0         40.0
# 2041760  zzw7ibZwvAk           30.0         40.0
# 2041761  zzwBazlj0Oc           30.0         40.0
# 2041762  zzwBtLuYJX8          130.0        140.0
# 2041763  zzwEaUOXSZs           30.0         40.0
# 2041764  zzwbG0dHLhI          150.0        160.0
# 2041765  zzwkvzWKJxI           50.0         60.0
# 2041766  zzwp5Z2qZKU          180.0        190.0
# 2041767  zzwsSOcZVTs            0.0         10.0
# 2041768  zzx-lGzV5dE           30.0         40.0
# 2041769  zzxIF9qnNfc           40.0         50.0
# 2041770  zzxK96M3XVY          110.0        120.0
# 2041771  zzxSVJFyAuc           30.0         40.0
# 2041772  zzxUh44r4Wg           30.0         40.0
# 2041773  zzxXdFWb-LM           50.0         60.0
# 2041774  zzxfWc5U3Wk          430.0        440.0
# 2041775  zzxgeSP8f5Y            7.0         17.0
# 2041776  zzy2Lgtpc5o            0.0         10.0
# 2041777  zzyJtkvCgQ4           90.0        100.0
# 2041778  zzy_5evgl3Y           30.0         40.0
# 2041779  zzycbwlBJXQ          180.0        190.0
# 2041780  zzyiWF0F9sg           20.0         30.0
# 2041781  zzyjKSkzyys           30.0         40.0
# 2041782  zzyr6l8MetA           60.0         70.0
# 2041783  zzyxEu9a2hw            0.0         10.0
# 2041784  zzyyleHsxfk           20.0         30.0
# 2041785  zzz-JsGPtxQ          120.0        130.0
# 2041786  zzz3PZXRQ_8           30.0         40.0
# 2041787  zzznDcamMpw            0.0         10.0
# 2041788  zzztDPePp4g          410.0        420.0
#
#                                            positive_labels  fireworks  \
# 0        /m/01g50p,/m/0284vy3,/m/06d_3,/m/07jdr,/m/07rwm0c      False
# 1                                                 /m/09x0r      False
# 2                                                 /m/04rlf      False
# 3                    /m/02qldy,/m/02zsn,/m/05zppz,/m/09x0r      False
# 4                                        /m/04rlf,/m/09x0r      False
# 5                                        /m/019jd,/m/07yv9      False
# 6                                        /m/04rlf,/m/0c1dj      False
# 7                    /m/012f08,/m/07yv9,/m/0k4j,/t/dd00134      False
# 8                                                 /m/04rlf      False
# 9                                                 /m/09x0r      False
# 10                                              /t/dd00067      False
# 11                                       /m/06h7j,/m/09x0r      False
# 12                                                /m/04rlf      False
# 13                                                /m/09x0r      False
# 14                                                /m/09x0r      False
# 15                                                /m/09x0r      False
# 16                     /m/018vs,/m/0342h,/m/04rlf,/m/04szw      False
# 17                                                /m/09x0r      False
# 18                    /m/0342h,/m/04rlf,/m/04szw,/m/0fx80y      False
# 19                            /m/07swgks,/m/0j2kx,/m/0j6m2      False
# 20                                                /m/07yv9      False
# 21                                                /m/04rlf      False
# 22                                       /m/04rlf,/m/09x0r      False
# 23                                              /t/dd00004      False
# 24                                      /m/04rlf,/m/0ggx5q      False
# 25                    /m/0342h,/m/04rlf,/m/04szw,/m/0fx80y      False
# 26                                                /m/09x0r      False
# 27                                                /m/09x0r      False
# 28                                     /m/04rlf,/m/07s8j8t      False
# 29                              /m/01bjv,/m/07yv9,/m/09x0r      False
# ...                                                    ...        ...
# 2041759               /m/01g50p,/m/06d_3,/m/07jdr,/m/07yv9      False
# 2041760                                  /m/04rlf,/m/09x0r      False
# 2041761                       /m/015p6,/m/0h0rv,/t/dd00125      False
# 2041762     /m/01xqw,/m/04rlf,/m/04szw,/m/0ggq0m,/m/0l14_3      False
# 2041763                                            /m/0jbk      False
# 2041764                               /m/01yg9g,/t/dd00066      False
# 2041765                                         /t/dd00125      False
# 2041766                                  /m/04rlf,/m/0cfdd      False
# 2041767                       /m/07r04,/m/07yv9,/t/dd00129      False
# 2041768                       /m/03kmc9,/m/04qvtq,/m/04rlf      False
# 2041769                                /m/07yv9,/t/dd00129      False
# 2041770                                           /m/09x0r      False
# 2041771                         /m/01bjv,/m/07yv9,/m/09x0r      False
# 2041772                                           /m/09x0r      False
# 2041773                                           /m/09x0r      False
# 2041774                                /m/09x0r,/t/dd00125      False
# 2041775                                /m/07q2z82,/m/07yv9      False
# 2041776                         /m/04rlf,/m/09x0r,/m/0dls3      False
# 2041777                                /m/09x0r,/t/dd00088      False
# 2041778                                  /m/04rlf,/m/09x0r      False
# 2041779                                 /m/0164x2,/m/04rlf      False
# 2041780                                 /m/01j4z9,/m/0_ksk      False
# 2041781                                         /t/dd00038      False
# 2041782                                /m/04rlf,/m/05148p4      False
# 2041783                                  /m/07r04,/m/07yv9      False
# 2041784               /m/05tny_,/m/068hy,/m/0bt9lr,/m/0jbk      False
# 2041785                                /m/015lz1,/m/0l14jd      False
# 2041786                                 /m/030rvx,/m/09x0r      False
# 2041787                                  /m/09ddx,/m/09x0r      False
# 2041788                       /m/04rlf,/m/09x0r,/t/dd00126      False
#
#          gunshots  background  other
# 0           False       False   True
# 1           False       False   True
# 2           False       False   True
# 3           False       False   True
# 4           False       False   True
# 5           False       False   True
# 6           False       False   True
# 7           False       False   True
# 8           False       False   True
# 9           False       False   True
# 10          False       False   True
# 11          False       False   True
# 12          False       False   True
# 13          False       False   True
# 14          False       False   True
# 15          False       False   True
# 16          False       False   True
# 17          False       False   True
# 18          False       False   True
# 19          False       False   True
# 20          False       False   True
# 21          False       False   True
# 22          False       False   True
# 23          False       False   True
# 24          False       False   True
# 25          False       False   True
# 26          False       False   True
# 27          False       False   True
# 28          False       False   True
# 29          False       False   True
# ...           ...         ...    ...
# 2041759     False       False   True
# 2041760     False       False   True
# 2041761     False        True  False
# 2041762     False       False   True
# 2041763     False       False   True
# 2041764     False       False   True
# 2041765     False        True  False
# 2041766     False       False   True
# 2041767     False        True  False
# 2041768     False       False   True
# 2041769     False        True  False
# 2041770     False       False   True
# 2041771     False       False   True
# 2041772     False       False   True
# 2041773     False       False   True
# 2041774     False        True  False
# 2041775     False       False   True
# 2041776     False       False   True
# 2041777     False       False   True
# 2041778     False       False   True
# 2041779     False       False   True
# 2041780     False       False   True
# 2041781     False       False   True
# 2041782     False       False   True
# 2041783     False       False   True
# 2041784     False       False   True
# 2041785     False       False   True
# 2041786     False       False   True
# 2041787     False       False   True
# 2041788     False        True  False
#
# [2041789 rows x 8 columns]

# %%
# lets store the unbalanced_train_segments which are tagged [gunshots,fireworks,background or noise]
# as unbalanced_train_tagged.csv
labels.to_csv(r'../data/preprocessed/unbalanced_train_tagged.csv')

# %%
#Checking out whats the distribution of the classes in the evaluation dataset

labels = pd.read_csv('eval_segments.csv', header = 2, quotechar = r'"', skipinitialspace=True)
labels['gunshots'] = labels['positive_labels'].str.contains(g_str)
labels['fireworks'] = labels['positive_labels'].str.contains(f_str)
labels['background'] = labels['positive_labels'].str.contains(b_str)
labels['other'] = True
labels['other'] = labels['other'] & ~labels['positive_labels'].str.contains(b_str) & ~labels['positive_labels'].str.contains(g_str) & ~labels['positive_labels'].str.contains(f_str)

gun_positive = labels[labels['gunshots']==True]
fireworks_positive = labels[labels['fireworks']==True]
background_positive = labels[labels['background']== True]
other_positive = labels[labels['other']==True]

d = {'Class' : ['Gunshots','Fireworks','Background','Other'], 'Total_samples' : [gun_positive.shape[0],fireworks_positive.shape[0],background_positive.shape[0],other_positive.shape[0]]}
df = pd.DataFrame(data=d)
df
# Out:
#         Class  Total_samples
# 0    Gunshots            292
# 1   Fireworks            161
# 2  Background           2053
# 3       Other          17890

# %%
sns.set(style="whitegrid")
sns.barplot(x='Class', y='Total_samples', data=df.reset_index())

# %%
#Creating an evaluation or Validation dataset. Make sure the validation set are equal and randomly sampled.
#output: tfrecord file which has YTID, start, end and positive labels of gun, fireworks, background and other.

labels = pd.read_csv('../data/raw/eval_segments.csv', header = 2, quotechar = r'"', skipinitialspace=True)
labels['gunshots'] = labels['positive_labels'].str.contains(g_str)
labels['fireworks'] = labels['positive_labels'].str.contains(f_str)
labels['background'] = labels['positive_labels'].str.contains(b_str)
labels['other'] = True
labels['other'] = labels['other'] & ~labels['positive_labels'].str.contains(b_str) & ~labels['positive_labels'].str.contains(g_str) & ~labels['positive_labels'].str.contains(f_str)

# gun_positive = labels[labels['gunshots']==True]
# fireworks_positive = labels[labels['fireworks']==True]
# background_positive = labels[labels['background']== True]
# other_positive = labels[labels['other']==True]
# print("gun samples:")
# print(gun_positive.shape[0])
# print("fireworks samples")
# print(fireworks_positive.shape[0])
# print("background samples")
# print(background_positive.shape[0])
# print("other samples")
# print(other_positive.shape[0])

# We found that there are 292 gun samples, 161 fireworks, 2053 background, 17890 Other  class in Evaluation set. 
# Lets make an evaluation dataset of 161 samples of each class. 

fireworks_positive = labels[labels['fireworks']==True]
gun_positive = labels[labels['gunshots']==True].sample(fireworks_positive.shape[0])
background_positive = labels[labels['background']==True].sample(fireworks_positive.shape[0])
other_positive = labels[labels['other']==True].sample(fireworks_positive.shape[0])

subset = gun_positive.append(fireworks_positive, ignore_index=True)
subset = subset.append(background_positive, ignore_index=True)
subset = subset.append(other_positive,ignore_index=True)

print(subset)
print(subset.shape[0])

#Remaining gun_positive = 131, background_positive = 1892, other_positive = 17729
#subset has all the dataset which contains gun_positive, background_
#Now lets take a look at the audio embedding files [tfrecord files]
files = glob.glob('../data/raw/audioset_v1_embeddings/eval/*')
print(files)
subset_ids = subset['# YTID'].values

i=0
writer = tf.python_io.TFRecordWriter('../data/preprocessed/eval_spotting_gunshots_subset.tfrecord')
for tfrecord in files:
    for example in tf.python_io.tf_record_iterator(tfrecord):
        tf_example = tf.train.Example.FromString(example)
        vid_id = tf_example.features.feature['video_id'].bytes_list.value[0].decode(encoding = 'UTF-8')
        if vid_id in subset_ids:
            writer.write(example)
            i= i+1
print(i)
writer.close()
# Out:
#           # YTID  start_seconds  end_seconds  \
# 0    zQPKy8HMbDc           60.0         70.0
# 1    rysr8w7aTuQ            0.0         10.0
# 2    RWZ8sRgIWBk          120.0        130.0
# 3    rnSSF1DaXww          420.0        430.0
# 4    MnEZwnRuQR8           30.0         40.0
# 5    ovgelLpt148           30.0         40.0
# 6    RAucmy-5bj4          530.0        540.0
# 7    pizFsY0yjss           30.0         40.0
# 8    R-NkPYfN3wA          150.0        160.0
# 9    LIPprUxFap8            6.0         16.0
# 10   -95a1RB0jHs           30.0         40.0
# 11   cAYlbC6C1gg           40.0         50.0
# 12   BqL897JQBSA            0.0         10.0
# 13   mC7nCm_mnwA           30.0         40.0
# 14   ldVtte9jK-s           30.0         40.0
# 15   82GoiIMS6Ig           30.0         40.0
# 16   Y_0Rzhwr20o            0.0         10.0
# 17   kTyq_6AnoSw           40.0         50.0
# 18   c9k4tTlQwmU           30.0         40.0
# 19   -22tna7KHzI           28.0         38.0
# 20   dLRlnhW9_Pc           70.0         80.0
# 21   Tc9sb71px5I           30.0         40.0
# 22   x7RLEgi_tGU          160.0        170.0
# 23   XzsPKZf62G0          420.0        430.0
# 24   uXVa0VyKdm0           24.0         34.0
# 25   S3dobukAML0          590.0        600.0
# 26   Dj9gyAoqmQ0           30.0         40.0
# 27   _3O_oBEzWAE          210.0        220.0
# 28   -9O1cb8z7Mk            0.0         10.0
# 29   t9PEpPvVNzI          310.0        320.0
# ..           ...            ...          ...
# 614  NM-54_fq4Ng           90.0        100.0
# 615  vm_7hPeTP7s            0.0          6.0
# 616  zaln4f5WgAs          110.0        120.0
# 617  BAUQY0e25DM           30.0         40.0
# 618  aSx7vaSqFXs          180.0        190.0
# 619  7y9RfZXJZsk           90.0        100.0
# 620  JCsX3ZKNR5M           30.0         40.0
# 621  U9PyY8Ldf9A            5.0         15.0
# 622  1Z8MIXXDPls           30.0         40.0
# 623  i8aWCOfrrJU          100.0        110.0
# 624  Wgu03JFYmQc          230.0        240.0
# 625  8Of35zlnvfU          200.0        210.0
# 626  QOiwMW2eh5g          420.0        430.0
# 627  -8Ds_ZrtQ9M           20.0         30.0
# 628  9aK2LBnTT2s           30.0         40.0
# 629  k8lCsWaHiko           30.0         40.0
# 630  2yumaMbGybU           10.0         20.0
# 631  0IzhjqyDzt8            0.0         10.0
# 632  0IwGsEzITQs           20.0         30.0
# 633  PURmJ-LJCBM           30.0         40.0
# 634  SNqfI9sjKH0          460.0        470.0
# 635  JU4CZ-GApu4           30.0         40.0
# 636  WVvr0UfwMq0            0.0         10.0
# 637  ThjLszNKcI4           30.0         40.0
# 638  WwJCpREP1zU           20.0         30.0
# 639  A9xrvsmJhjo           30.0         40.0
# 640  SaBcy6-cLZg           80.0         90.0
# 641  kMK10SknFAI          280.0        290.0
# 642  XcupCkc_mbc           20.0         30.0
# 643  4kNSVFyrnQU           30.0         40.0
#
#                                        positive_labels  gunshots  fireworks  \
# 0                                  /m/032s66,/m/073cg4      True      False
# 1                                  /m/032s66,/m/073cg4      True      False
# 2                                    /m/032s66,/m/0_1c      True      False
# 3                                  /m/032s66,/m/073cg4      True      False
# 4                                    /m/032s66,/m/0_1c      True      False
# 5                                    /m/032s66,/m/0_1c      True      False
# 6                         /m/02z32qm,/m/04rlf,/m/09x0r      True      False
# 7                                   /m/014zdl,/m/09x0r      True      False
# 8                                  /m/032s66,/m/073cg4      True      False
# 9                        /m/014zdl,/m/07pxg6y,/m/09x0r      True      False
# 10                                /m/014zdl,/m/07pxg6y      True      False
# 11                        /m/02z32qm,/m/04rlf,/m/09x0r      True      False
# 12                                          /m/02z32qm      True      False
# 13                                 /m/032s66,/m/073cg4      True      False
# 14                                   /m/032s66,/m/0_1c      True      False
# 15                                   /m/032s66,/m/0_1c      True      False
# 16                                           /m/014zdl      True      False
# 17                                   /m/032s66,/m/0_1c      True      False
# 18                                   /m/032s66,/m/0_1c      True      False
# 19                                           /m/014zdl      True      False
# 20                                  /m/032s66,/m/04zjc      True      False
# 21                                   /m/032s66,/m/0_1c      True      False
# 22                                  /m/032s66,/m/04zjc      True      False
# 23                                  /m/032s66,/m/04zjc      True      False
# 24                                   /m/032s66,/m/0_1c      True      False
# 25                                          /m/02z32qm      True      False
# 26                          /m/032s66,/m/04zjc,/m/0_1c      True      False
# 27                                /m/02z32qm,/m/032s66      True      False
# 28                                          /m/02z32qm      True      False
# 29                                  /m/032s66,/m/04zjc      True      False
# ..                                                 ...       ...        ...
# 614                                         /m/07pjjrj     False      False
# 615                                          /m/030rvx     False      False
# 616                                 /m/01h8n0,/m/09x0r     False      False
# 617                                 /m/01c194,/m/04rlf     False      False
# 618                                /m/025wky1,/m/09x0r     False      False
# 619                                  /m/04rlf,/m/0ln16     False      False
# 620                        /m/04rlf,/m/09x0r,/m/0ggq0m     False      False
# 621                                          /m/01hsr_     False      False
# 622                                /m/06wzb,/m/07rjwbb     False      False
# 623                                           /m/039jq     False      False
# 624  /m/019jd,/m/034srq,/m/03m9d0z,/m/0hsrw,/t/dd00092     False      False
# 625                                 /m/01hsr_,/m/09x0r     False      False
# 626                                /m/025wky1,/m/09x0r     False      False
# 627                                         /m/02x984l     False      False
# 628              /m/07rknqz,/m/07yv9,/m/09x0r,/m/0h9mv     False      False
# 629                     /m/025rv6n,/m/07qwf61,/m/0dbvp     False      False
# 630                                  /m/0192l,/m/085jw     False      False
# 631                                          /m/03w41f     False      False
# 632                /m/012f08,/m/07yv9,/m/0h9mv,/m/0k4j     False      False
# 633                        /m/07r_k2n,/m/09x0r,/m/0jbk     False      False
# 634                                         /m/07qfgpx     False      False
# 635                       /m/015y_n,/m/04rlf,/m/05rwpb     False      False
# 636                     /m/04rlf,/m/07q0yl5,/m/07s0dtb     False      False
# 637                                /m/025wky1,/m/09x0r     False      False
# 638     /m/01kcd,/m/01p970,/m/026t6,/m/06ncr,/m/0l14md     False      False
# 639                                         /m/07pqc89     False      False
# 640                                           /m/07n_g     False      False
# 641                                /m/04rlf,/m/07prgkl     False      False
# 642                                /m/07prgkl,/m/09x0r     False      False
# 643                                /m/07qs1cx,/m/09x0r     False      False
#
#      background  other
# 0         False  False
# 1         False  False
# 2         False  False
# 3         False  False
# 4         False  False
# 5         False  False
# 6         False  False
# 7         False  False
# 8         False  False
# 9         False  False
# 10        False  False
# 11        False  False
# 12        False  False
# 13        False  False
# 14        False  False
# 15        False  False
# 16        False  False
# 17        False  False
# 18        False  False
# 19        False  False
# 20        False  False
# 21        False  False
# 22        False  False
# 23        False  False
# 24        False  False
# 25        False  False
# 26        False  False
# 27        False  False
# 28        False  False
# 29        False  False
# ..          ...    ...
# 614       False   True
# 615       False   True
# 616       False   True
# 617       False   True
# 618       False   True
# 619       False   True
# 620       False   True
# 621       False   True
# 622       False   True
# 623       False   True
# 624       False   True
# 625       False   True
# 626       False   True
# 627       False   True
# 628       False   True
# 629       False   True
# 630       False   True
# 631       False   True
# 632       False   True
# 633       False   True
# 634       False   True
# 635       False   True
# 636       False   True
# 637       False   True
# 638       False   True
# 639       False   True
# 640       False   True
# 641       False   True
# 642       False   True
# 643       False   True
#
# [644 rows x 8 columns]
# 644
# ['audioset_v1_embeddings/eval/5V.tfrecord', 'audioset_v1_embeddings/eval/40.tfrecord', 'audioset_v1_embeddings/eval/5W.tfrecord', 'audioset_v1_embeddings/eval/41.tfrecord', 'audioset_v1_embeddings/eval/gR.tfrecord', 'audioset_v1_embeddings/eval/F4.tfrecord', 'audioset_v1_embeddings/eval/Y9.tfrecord', 'audioset_v1_embeddings/eval/Gs.tfrecord', 'audioset_v1_embeddings/eval/F5.tfrecord', 'audioset_v1_embeddings/eval/Y8.tfrecord', 'audioset_v1_embeddings/eval/7k.tfrecord', 'audioset_v1_embeddings/eval/6-.tfrecord', 'audioset_v1_embeddings/eval/7J.tfrecord', 'audioset_v1_embeddings/eval/Zb.tfrecord', 'audioset_v1_embeddings/eval/eo.tfrecord', 'audioset_v1_embeddings/eval/Zc.tfrecord', 'audioset_v1_embeddings/eval/EN.tfrecord', 'audioset_v1_embeddings/eval/LM.tfrecord', 'audioset_v1_embeddings/eval/Sa.tfrecord', 'audioset_v1_embeddings/eval/ll.tfrecord', 'audioset_v1_embeddings/eval/NP.tfrecord', 'audioset_v1_embeddings/eval/O6.tfrecord', 'audioset_v1_embeddings/eval/Nq.tfrecord', 'audioset_v1_embeddings/eval/O7.tfrecord', 'audioset_v1_embeddings/eval/af.tfrecord', 'audioset_v1_embeddings/eval/aG.tfrecord', 'audioset_v1_embeddings/eval/3B.tfrecord', 'audioset_v1_embeddings/eval/3c.tfrecord', 'audioset_v1_embeddings/eval/l_.tfrecord', 'audioset_v1_embeddings/eval/CZ.tfrecord', 'audioset_v1_embeddings/eval/09.tfrecord', 'audioset_v1_embeddings/eval/08.tfrecord', 'audioset_v1_embeddings/eval/T2.tfrecord', 'audioset_v1_embeddings/eval/Jy.tfrecord', 'audioset_v1_embeddings/eval/uT.tfrecord', 'audioset_v1_embeddings/eval/t3.tfrecord', 'audioset_v1_embeddings/eval/jx.tfrecord', 'audioset_v1_embeddings/eval/Uu.tfrecord', 'audioset_v1_embeddings/eval/WI.tfrecord', 'audioset_v1_embeddings/eval/Hd.tfrecord', 'audioset_v1_embeddings/eval/WH.tfrecord', 'audioset_v1_embeddings/eval/hE.tfrecord', 'audioset_v1_embeddings/eval/Yl.tfrecord', 'audioset_v1_embeddings/eval/fA.tfrecord', 'audioset_v1_embeddings/eval/yM.tfrecord', 'audioset_v1_embeddings/eval/4E.tfrecord', 'audioset_v1_embeddings/eval/4d.tfrecord', 'audioset_v1_embeddings/eval/z7.tfrecord', 'audioset_v1_embeddings/eval/z6.tfrecord', 'audioset_v1_embeddings/eval/6x.tfrecord', 'audioset_v1_embeddings/eval/6y.tfrecord', 'audioset_v1_embeddings/eval/rS.tfrecord', 'audioset_v1_embeddings/eval/l8.tfrecord', 'audioset_v1_embeddings/eval/S5.tfrecord', 'audioset_v1_embeddings/eval/rr.tfrecord', 'audioset_v1_embeddings/eval/L9.tfrecord', 'audioset_v1_embeddings/eval/s4.tfrecord', 'audioset_v1_embeddings/eval/0_.tfrecord', 'audioset_v1_embeddings/eval/PN.tfrecord', 'audioset_v1_embeddings/eval/OC.tfrecord', 'audioset_v1_embeddings/eval/pO.tfrecord', 'audioset_v1_embeddings/eval/oB.tfrecord', 'audioset_v1_embeddings/eval/37.tfrecord', 'audioset_v1_embeddings/eval/2q.tfrecord', 'audioset_v1_embeddings/eval/36.tfrecord', 'audioset_v1_embeddings/eval/2P.tfrecord', 'audioset_v1_embeddings/eval/a3.tfrecord', 'audioset_v1_embeddings/eval/A2.tfrecord', 'audioset_v1_embeddings/eval/0l.tfrecord', 'audioset_v1_embeddings/eval/0m.tfrecord', 'audioset_v1_embeddings/eval/BH.tfrecord', 'audioset_v1_embeddings/eval/BI.tfrecord', 'audioset_v1_embeddings/eval/9n.tfrecord', 'audioset_v1_embeddings/eval/9O.tfrecord', 'audioset_v1_embeddings/eval/TG.tfrecord', 'audioset_v1_embeddings/eval/kj.tfrecord', 'audioset_v1_embeddings/eval/j-.tfrecord', 'audioset_v1_embeddings/eval/tF.tfrecord', 'audioset_v1_embeddings/eval/KK.tfrecord', 'audioset_v1_embeddings/eval/h1.tfrecord', 'audioset_v1_embeddings/eval/Y_.tfrecord', 'audioset_v1_embeddings/eval/iw.tfrecord', 'audioset_v1_embeddings/eval/vZ.tfrecord', 'audioset_v1_embeddings/eval/h0.tfrecord', 'audioset_v1_embeddings/eval/IV.tfrecord', 'audioset_v1_embeddings/eval/hN.tfrecord', 'audioset_v1_embeddings/eval/wC.tfrecord', 'audioset_v1_embeddings/eval/ho.tfrecord', 'audioset_v1_embeddings/eval/wb.tfrecord', 'audioset_v1_embeddings/eval/t8.tfrecord', 'audioset_v1_embeddings/eval/k5.tfrecord', 'audioset_v1_embeddings/eval/Js.tfrecord', 'audioset_v1_embeddings/eval/t9.tfrecord',  ...
# WARNING:tensorflow:From <ipython-input-48-43b0d321fbb8>:47: tf_record_iterator (from tensorflow.python.lib.io.tf_record) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use eager execution and:
# `tf.data.TFRecordDataset(path)`
# 229

# %%
# !pip install tqdm
# Out:
# Collecting tqdm
#   Downloading https://files.pythonhosted.org/packages/45/af/685bf3ce889ea191f3b916557f5677cc95a5e87b2fa120d74b5dd6d049d0/tqdm-4.32.1-py2.py3-none-any.whl (49kB)
#      |████████████████████████████████| 51kB 1.1MB/s eta 0:00:01
# Installing collected packages: tqdm
# Successfully installed tqdm-4.32.1
# Note: you may need to restart the kernel to use updated packages.

# %%
from tqdm import tqdm

# %%
# Now open the unbalanced_train data 
labels = pd.read_csv('../data/raw/unbalanced_train_segments.csv',header=2, quotechar=r'"',skipinitialspace=True)

# %%
print(labels.shape[0])
# Out:
# 2041789

# %%
labels['gunshots'] = labels['positive_labels'].str.contains(g_str)
labels['fireworks'] = labels['positive_labels'].str.contains(f_str)
labels['background'] = labels['positive_labels'].str.contains(b_str)
labels['other'] = True
labels['other'] = labels['other'] & ~labels['positive_labels'].str.contains(b_str) & ~labels['positive_labels'].str.contains(g_str) & ~labels['positive_labels'].str.contains(f_str)

fireworks_positive = labels[labels['fireworks']==True]
print(fireworks_positive.shape[0])
gun_positive = labels[labels['gunshots']==True].sample(fireworks_positive.shape[0])
print(gun_positive.shape[0])
background_positive = labels[labels['background']==True].sample(fireworks_positive.shape[0])
print(background_positive.shape[0])
other_positive = labels[labels['other']==True].sample(fireworks_positive.shape[0])
print(other_positive.shape[0])

#firework samples = 5708, gunshot samples = 8831 , background_samples = 194974, other = 1833813
#There is a strong class imbalance in this problem. Therefore, for now,we will handle this class
#imbalance by making sure all classes is of size fireworks. 

subset = gun_positive.append(fireworks_positive, ignore_index=True)
subset = subset.append(background_positive, ignore_index=True)
subset = subset.append(other_positive,ignore_index=True)

print(subset)
print(subset.shape[0])


import glob
files = glob.glob('../data/raw/audioset_v1_embeddings/unbal_train/*')
subset_ids= subset['# YTID'].values

i=0
writer = tf.python_io.TFRecordWriter('../data/preprocessed/bal_spotgun_subset.tfrecord')
for tfrecord in tqdm(files):
    for example in tf.python_io.tf_record_iterator(tfrecord):
        tf_example = tf.train.Example.FromString(example)
        vid_id = tf_example.features.feature['video_id'].bytes_list.value[0].decode(encoding = 'UTF-8')
        if vid_id in subset_ids:
            writer.write(example)
            i+=1
print(i)
# This bal_spotgun_subset.tfrecord just contains [start, end, vid, labels] of gunshot,fireworks, background, other classes
writer.close()
# Out:
# 5708
# 5708
# 5708
# 5708
#   0%|          | 0/1444 [00:00<?, ?it/s]
#             # YTID  start_seconds  end_seconds  \
# 0      v_m3hZZnmeU          400.0        410.0
# 1      J5WZgg74HTY           30.0         40.0
# 2      hbmvKC3zGZ4          460.0        470.0
# 3      A0BhGxGQGpo            0.0          7.0
# 4      eq0zT1OZ_gM           30.0         40.0
# 5      xm3ShwwqXLc          220.0        230.0
# 6      SgS19R3ZdkU            0.0          6.0
# 7      kJpgOeqK9I4          340.0        350.0
# 8      NmUifbk46xM           11.0         21.0
# 9      bpgnhai_EnA           30.0         40.0
# 10     V7gMO1GKuGQ           70.0         80.0
# 11     UDUpmQG0gKo          310.0        320.0
# 12     eEkBsPyhYO4          460.0        470.0
# 13     _LDvXU9KU4o          340.0        350.0
# 14     Df9Ej08lZJA           50.0         60.0
# 15     8L8R0PiqZi0           10.0         20.0
# 16     ANBnHEYzdyc          130.0        140.0
# 17     9lkBdLgjFoE           10.0         20.0
# 18     RdtbzqK2rXQ          240.0        250.0
# 19     Y4vCEAX9RXQ          170.0        180.0
# 20     Ote0apnGymc            3.0         13.0
# 21     eeOVaF6Iam4           10.0         20.0
# 22     AiAwMWUy-rg           70.0         80.0
# 23     Zrlq4qN43tc            3.0         13.0
# 24     q3M0WSbsNzY            0.0         10.0
# 25     n8KYZWDf3wg           16.0         26.0
# 26     8FPmAmGvldY          480.0        490.0
# 27     IQacssJX_Zw           30.0         40.0
# 28     Gf0pQ9z7GMc          140.0        150.0
# 29     fa9PkZ0XBPU            6.0         16.0
# ...            ...            ...          ...
# 22802  9je557kHAcc           70.0         80.0
# 22803  P2xGBYFcw0A           30.0         40.0
# 22804  5Wgq2XPmGa4           20.0         30.0
# 22805  OlHU_tVAGh4            1.0         11.0
# 22806  R8qXjgikmZk          190.0        200.0
# 22807  XY699eDfBIY          220.0        230.0
# 22808  PGHl1ITp8gA           30.0         40.0
# 22809  E88jdfStbWM           30.0         40.0
# 22810  MlovuzXeug4           30.0         40.0
# 22811  bjXNg1yNLt8           30.0         40.0
# 22812  ESYrveyFHD8           13.0         23.0
# 22813  7MkEiyah8e0           30.0         40.0
# 22814  dijm16FCroo           50.0         60.0
# 22815  TrPRP1581tw           30.0         40.0
# 22816  FStp0WKlHxo           30.0         40.0
# 22817  BJ75XMhTZoI           30.0         40.0
# 22818  fWeycGGvOiw          240.0        250.0
# 22819  6ipJW_2r40o           30.0         40.0
# 22820  Hvu514cO2l0           30.0         40.0
# 22821  6qPiaracCFY           30.0         40.0
# 22822  inoOuJL2eec           30.0         40.0
# 22823  UkgWhEELr3g           30.0         40.0
# 22824  Xw1n0IeQM9A           60.0         70.0
# 22825  9NgtEe6ojro           20.0         30.0
# 22826  _s-qjqp0To4           10.0         20.0
# 22827  Xhy0qcFrRmU           80.0         90.0
# 22828  uMfYuJ_ekLg           30.0         40.0
# 22829  3w0V-jR5Emc           30.0         40.0
# 22830  FFUzodUJD-Y          110.0        120.0
# 22831  TPHtlYixq8w           30.0         40.0
#
#                                         positive_labels  gunshots  fireworks  \
# 0                                    /m/032s66,/m/04zjc      True      False
# 1                                    /m/014zdl,/m/09x0r      True      False
# 2                                   /m/02z32qm,/m/09x0r      True      False
# 3                       /m/014zdl,/m/07pxg6y,/m/07qsvvw      True       True
# 4                                              /m/04zjc      True      False
# 5                                    /m/032s66,/m/04rlf      True      False
# 6                                             /m/032s66      True      False
# 7                                              /m/04zjc      True      False
# 8                                    /m/014zdl,/m/09x0r      True      False
# 9                                             /m/032s66      True      False
# 10                                            /m/032s66      True      False
# 11                                  /m/032s66,/m/073cg4      True      False
# 12                                            /m/032s66      True      False
# 13                                            /m/032s66      True      False
# 14                                            /m/032s66      True      False
# 15                                 /m/014zdl,/m/07qqyl4      True      False
# 16                                            /m/032s66      True      False
# 17                                  /m/032s66,/m/073cg4      True      False
# 18                                   /m/032s66,/m/04zjc      True      False
# 19                                   /m/032s66,/m/04zjc      True      False
# 20                        /m/014zdl,/m/07qsvvw,/m/09x0r      True       True
# 21                                  /m/02z32qm,/m/04rlf      True      False
# 22                                   /m/032s66,/m/04zjc      True      False
# 23                                            /m/014zdl      True      False
# 24                                    /m/04zjc,/m/09x0r      True      False
# 25                                              /m/0_1c      True      False
# 26                                  /m/02z32qm,/m/09x0r      True      False
# 27                                   /m/032s66,/m/04zjc      True      False
# 28                                            /m/032s66      True      False
# 29               /m/014zdl,/m/04rlf,/m/07qsvvw,/m/09x0r      True       True
# ...                                                 ...       ...        ...
# 22802                                          /m/04rlf     False      False
# 22803                                 /m/04rlf,/m/09x0r     False      False
# 22804    /m/01z5f,/m/068hy,/m/07qf0zm,/m/0bt9lr,/m/0jbk     False      False
# 22805                                        /m/07qjznl     False      False
# 22806                                /m/015lz1,/m/04rlf     False      False
# 22807                                 /m/02x8m,/m/04rlf     False      False
# 22808                                 /m/04rlf,/m/09x0r     False      False
# 22809                                 /m/04rlf,/m/09x0r     False      False
# 22810                                          /m/09x0r     False      False
# 22811                                 /m/04rlf,/m/0838f     False      False
# 22812                                        /m/07rjwbb     False      False
# 22813                                          /m/09x0r     False      False
# 22814               /m/03lty,/m/04rlf,/m/06by7,/m/0dls3     False      False
# 22815                                          /m/09x0r     False      False
# 22816                                 /m/04rlf,/m/09x0r     False      False
# 22817                                          /m/09x0r     False      False
# 22818                                 /m/04rlf,/m/09x0r     False      False
# 22819                      /m/02qldy,/m/05zppz,/m/09x0r     False      False
# 22820                                 /m/04rlf,/m/09x0r     False      False
# 22821                                          /m/04rlf     False      False
# 22822                                        /t/dd00067     False      False
# 22823                                          /m/09x0r     False      False
# 22824                                          /m/03l9g     False      False
# 22825                                 /m/02lkt,/m/04rlf     False      False
# 22826                                          /m/09x0r     False      False
# 22827  /m/015lz1,/m/0342h,/m/04szw,/m/07s0s5r,/m/0fx80y     False      False
# 22828                                          /m/09x0r     False      False
# 22829          /m/04rlf,/m/0l14jd,/t/dd00003,/t/dd00004     False      False
# 22830                       /m/04rlf,/m/05fw6t,/m/09x0r     False      False
# 22831                                          /m/09x0r     False      False
#
#        background  other
# 0           False  False
# 1           False  False
# 2           False  False
# 3           False  False
# 4           False  False
# 5           False  False
# 6           False  False
# 7           False  False
# 8           False  False
# 9           False  False
# 10          False  False
# 11          False  False
# 12          False  False
# 13          False  False
# 14          False  False
# 15          False  False
# 16          False  False
# 17          False  False
# 18          False  False
# 19          False  False
# 20          False  False
# 21          False  False
# 22          False  False
# 23          False  False
# 24          False  False
# 25          False  False
# 26          False  False
# 27          False  False
# 28          False  False
# 29          False  False
# ...           ...    ...
# 22802       False   True
# 22803       False   True
# 22804       False   True
# 22805       False   True
# 22806       False   True
# 22807       False   True
# 22808       False   True
# 22809       False   True
# 22810       False   True
# 22811       False   True
# 22812       False   True
# 22813       False   True
# 22814       False   True
# 22815       False   True
# 22816       False   True
# 22817       False   True
# 22818       False   True
# 22819       False   True
# 22820       False   True
# 22821       False   True
# 22822       False   True
# 22823       False   True
# 22824       False   True
# 22825       False   True
# 22826       False   True
# 22827       False   True
# 22828       False   True
# 22829       False   True
# 22830       False   True
# 22831       False   True
#
# [22832 rows x 8 columns]
# 22832
# 100%|██████████| 1444/1444 [21:30<00:00,  1.55it/s]
# 8128

# %%
## Auxilarry tests: 
#to iterate and see what are the contents in any tf_record file. 

# records = list(tf.python_io.tf_record_iterator('preprocessed_data/bal_spotgun_subset.tfrecord'))
# print(len(records))
# i=0
# for example in records:
#     tf_example = tf.train.Example.FromString(example)
#     audio_mbed = tf_example.feature_list['audio_embedding']
#     print("record number")
#     print(i)
#     print(tf_example)
#     print(audio_mbed)
#     i = i+1

# #vid_id = tf_example.features.feature['video_id'].bytes_list.value[0].decode(encoding = 'UTF-8')
# #audio_mbed = tf_example.feature_lists.feature_list['audio_embedding']
